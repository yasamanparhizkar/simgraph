# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# add the path to my packages to system paths so they can be imported
import sys
# sys.path.append('/home/yasamanparhizkar/Documents/yorku/01_thesis/simgraph/code/my_packages')
sys.path.append('F:/Users/yasam/Documents/GitHub/simgraph/code/my_packages')
# sys.path.append('/home/yasamanparhizkar/Documents/thesis/code/my_packages')

import dataprocess.data_handler_03 as dh
# import rnn_assess as rnas
import gru_assess as rnas
# import lstm_assess as rnas
import load_data as ld

# %% [markdown]
# # Assess the GRU model for various training set sizes

# %% [markdown]
# # Load the data

# %%
# load all spike data from file
spikes_dp = '../../../../local_data/original_files/spikes.npy'
grouped_data = ld.load_grouped_spikes(spikes_dp) # OR grouping
grouped_data.shape
# Out:
# (297, 1141, 1)

# %%
# data_params = ld.get_data_params('sift3d', grouped_data)
data_params = ld.get_data_params('mnist-sift', grouped_data)
print(data_params)
# Out:
# **Warning: Check the sampling rate.**
#
# {'func': <function datapoint_sift at 0x0000020D319C1430>, 'lbl_func': <function get_mnist_labels at 0x0000020D319C1E50>, 'features_dp': '../../../data/fe_exp/mnist-sift/', 'spike_data': None, 'group_id': None, 'transform': <function transform_mnistsift at 0x0000020D33066550>, 'ind_min': 0, 'ind_max': 13203, 'feature_id': 'mnist-sift'}

# %%
# ld.sr_sift3d = 2 # sampling rate
ld.sr_mnistsift = 4 # sampling rate

train_num = 10
val_num = 5

train_num, val_num, train_data, val_data = \
dh.random_train_val_balanced(train_num, val_num, data_params, seed=1342)

# show statistics
print('feature_id: ', data_params['feature_id'])
print('train_num = ', train_num, ', val_num = ', val_num)
print('number of features: ', train_data['des'].shape[1])
print('training data contains {} points ({:.2f}%) of label 1.'
      .format(np.sum(train_data['lbls'] == 1), np.sum(train_data['lbls'] == 1)*100/train_num))
print('validation data contains {} points ({:.2f}%) of label 1.'
      .format(np.sum(val_data['lbls'] == 1), np.sum(val_data['lbls'] == 1)*100/val_num))
# print('train_smpls = ', train_data['smpls'], '\nval_smpls = ', val_data['smpls'])
# print('train_lbls = ', train_data['lbls'], '\nval_lbls = ', val_data['lbls'])
# print('train_des = ', train_data['des'], '\nval_des = ', val_data['des'])
# Out:
# feature_id:  mnist-sift
# train_num =  10 , val_num =  5
# number of features:  64
# training data contains 5 points (50.00%) of label 1.
# validation data contains 2 points (40.00%) of label 1.

# %% [markdown]
# # Assess

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters 
learning_rate = 0.001
num_classes = 2
num_epochs = 150
# batch_size = 50

# 3d-sift
sequence_length = 32
input_size = 12
# mnist-sift
sequence_length = 2
input_size = 32

hidden_size = 128
num_layers = 1

seed = None # for random datapoint choice

# %%
# train_sizes = [50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650]
# val_num = 50

# test sizes
train_sizes = [40, 45, 50, 55, 60, 65, 70]
val_num = 50

train_its = 100
val_its = 10

# %%
val_acc_means, val_acc_stds = \
rnas.assess_rnn(train_sizes, val_num, train_its, val_its, data_params, sequence_length, 
               input_size, hidden_size, num_layers, num_classes, device, learning_rate, num_epochs,
               show_messages=False, seed=None)
# Out:
# train size: 40 iteration: 1/100
# train size: 40 iteration: 2/100
# train size: 40 iteration: 3/100
# train size: 40 iteration: 4/100
# train size: 40 iteration: 5/100
# train size: 40 iteration: 6/100
# train size: 40 iteration: 7/100
# train size: 40 iteration: 8/100
# train size: 40 iteration: 9/100
# train size: 40 iteration: 10/100
# train size: 40 iteration: 11/100
# train size: 40 iteration: 12/100
# train size: 40 iteration: 13/100
# train size: 40 iteration: 14/100
# train size: 40 iteration: 15/100
# train size: 40 iteration: 16/100
# train size: 40 iteration: 17/100
# train size: 40 iteration: 18/100
# train size: 40 iteration: 19/100
# train size: 40 iteration: 20/100
# train size: 40 iteration: 21/100
# train size: 40 iteration: 22/100
# train size: 40 iteration: 23/100
# train size: 40 iteration: 24/100
# train size: 40 iteration: 25/100
# train size: 40 iteration: 26/100
# train size: 40 iteration: 27/100
# train size: 40 iteration: 28/100
# train size: 40 iteration: 29/100
# train size: 40 iteration: 30/100
# train size: 40 iteration: 31/100
# train size: 40 iteration: 32/100
# train size: 40 iteration: 33/100
# train size: 40 iteration: 34/100
# train size: 40 iteration: 35/100
# train size: 40 iteration: 36/100
# train size: 40 iteration: 37/100
# train size: 40 iteration: 38/100
# train size: 40 iteration: 39/100
# train size: 40 iteration: 40/100
# train size: 40 iteration: 41/100
# train size: 40 iteration: 42/100
# train size: 40 iteration: 43/100
# train size: 40 iteration: 44/100
# train size: 40 iteration: 45/100
# train size: 40 iteration: 46/100
# train size: 40 iteration: 47/100
# train size: 40 iteration: 48/100
# train size: 40 iteration: 49/100
# train size: 40 iteration: 50/100
# train size: 40 iteration: 51/100
# train size: 40 iteration: 52/100
# train size: 40 iteration: 53/100
# train size: 40 iteration: 54/100
# train size: 40 iteration: 55/100
# train size: 40 iteration: 56/100
# train size: 40 iteration: 57/100
# train size: 40 iteration: 58/100
# train size: 40 iteration: 59/100
# train size: 40 iteration: 60/100
# train size: 40 iteration: 61/100
# train size: 40 iteration: 62/100
# train size: 40 iteration: 63/100
# train size: 40 iteration: 64/100
# train size: 40 iteration: 65/100
# train size: 40 iteration: 66/100
# train size: 40 iteration: 67/100
# train size: 40 iteration: 68/100
# train size: 40 iteration: 69/100
# train size: 40 iteration: 70/100
# train size: 40 iteration: 71/100
# train size: 40 iteration: 72/100
# train size: 40 iteration: 73/100
# train size: 40 iteration: 74/100
# train size: 40 iteration: 75/100
# train size: 40 iteration: 76/100
# train size: 40 iteration: 77/100
# train size: 40 iteration: 78/100
# train size: 40 iteration: 79/100
# train size: 40 iteration: 80/100
# train size: 40 iteration: 81/100
# train size: 40 iteration: 82/100
# train size: 40 iteration: 83/100
# train size: 40 iteration: 84/100
# train size: 40 iteration: 85/100
# train size: 40 iteration: 86/100
# train size: 40 iteration: 87/100
# train size: 40 iteration: 88/100
# train size: 40 iteration: 89/100
# train size: 45 iteration: 79/100
# train size: 45 iteration: 80/100
# train size: 45 iteration: 81/100
# train size: 45 iteration: 82/100
# train size: 45 iteration: 83/100
# train size: 45 iteration: 84/100
# train size: 45 iteration: 85/100
# train size: 45 iteration: 86/100
# train size: 45 iteration: 87/100
# train size: 45 iteration: 88/100
# train size: 45 iteration: 89/100
# train size: 45 iteration: 90/100
# train size: 45 iteration: 91/100
# train size: 45 iteration: 92/100
# train size: 45 iteration: 93/100
# train size: 45 iteration: 94/100
# train size: 45 iteration: 95/100
# train size: 45 iteration: 96/100
# train size: 45 iteration: 97/100
# train size: 45 iteration: 98/100
# train size: 45 iteration: 99/100
# train size: 45 iteration: 100/100
# train size: 45 	mean acc: 89.166 	std: 4.490483715592342
# train size: 50 iteration: 1/100
# train size: 50 iteration: 2/100
# train size: 50 iteration: 3/100
# train size: 50 iteration: 4/100
# train size: 50 iteration: 5/100
# train size: 50 iteration: 6/100
# train size: 50 iteration: 7/100
# train size: 50 iteration: 8/100
# train size: 50 iteration: 9/100
# train size: 50 iteration: 10/100
# train size: 50 iteration: 11/100
# train size: 50 iteration: 12/100
# train size: 50 iteration: 13/100
# train size: 50 iteration: 14/100
# train size: 50 iteration: 15/100
# train size: 50 iteration: 16/100
# train size: 50 iteration: 17/100
# train size: 50 iteration: 18/100
# train size: 50 iteration: 19/100
# train size: 50 iteration: 20/100
# train size: 50 iteration: 21/100
# train size: 50 iteration: 22/100
# train size: 50 iteration: 23/100
# train size: 50 iteration: 24/100
# train size: 50 iteration: 25/100
# train size: 50 iteration: 26/100
# train size: 50 iteration: 27/100
# train size: 50 iteration: 28/100
# train size: 50 iteration: 29/100
# train size: 50 iteration: 30/100
# train size: 50 iteration: 31/100
# train size: 50 iteration: 32/100
# train size: 50 iteration: 33/100
# train size: 50 iteration: 34/100
# train size: 50 iteration: 35/100
# train size: 50 iteration: 36/100
# train size: 50 iteration: 37/100
# train size: 50 iteration: 38/100
# train size: 50 iteration: 39/100
# train size: 50 iteration: 40/100
# train size: 50 iteration: 41/100
# train size: 50 iteration: 42/100
# train size: 50 iteration: 43/100
# train size: 50 iteration: 44/100
# train size: 50 iteration: 45/100
# train size: 50 iteration: 46/100
# train size: 50 iteration: 47/100
# train size: 50 iteration: 48/100
# train size: 50 iteration: 49/100
# train size: 50 iteration: 50/100
# train size: 50 iteration: 51/100
# train size: 50 iteration: 52/100
# train size: 50 iteration: 53/100
# train size: 50 iteration: 54/100
# train size: 50 iteration: 55/100
# train size: 50 iteration: 56/100
# train size: 50 iteration: 57/100
# train size: 50 iteration: 58/100
# train size: 50 iteration: 59/100
# train size: 50 iteration: 60/100
# train size: 50 iteration: 61/100
# train size: 50 iteration: 62/100
# train size: 50 iteration: 63/100
# train size: 50 iteration: 64/100
# train size: 50 iteration: 65/100
# train size: 50 iteration: 66/100
# train size: 50 iteration: 67/100
# train size: 60 iteration: 46/100
# train size: 60 iteration: 47/100
# train size: 60 iteration: 48/100
# train size: 60 iteration: 49/100
# train size: 60 iteration: 50/100
# train size: 60 iteration: 51/100
# train size: 60 iteration: 52/100
# train size: 60 iteration: 53/100
# train size: 60 iteration: 54/100
# train size: 60 iteration: 55/100
# train size: 60 iteration: 56/100
# train size: 60 iteration: 57/100
# train size: 60 iteration: 58/100
# train size: 60 iteration: 59/100
# train size: 60 iteration: 60/100
# train size: 60 iteration: 61/100
# train size: 60 iteration: 62/100
# train size: 60 iteration: 63/100
# train size: 60 iteration: 64/100
# train size: 60 iteration: 65/100
# train size: 60 iteration: 66/100
# train size: 60 iteration: 67/100
# train size: 60 iteration: 68/100
# train size: 60 iteration: 69/100
# train size: 60 iteration: 70/100
# train size: 60 iteration: 71/100
# train size: 60 iteration: 72/100
# train size: 60 iteration: 73/100
# train size: 60 iteration: 74/100
# train size: 60 iteration: 75/100
# train size: 60 iteration: 76/100
# train size: 60 iteration: 77/100
# train size: 60 iteration: 78/100
# train size: 60 iteration: 79/100
# train size: 60 iteration: 80/100
# train size: 60 iteration: 81/100
# train size: 60 iteration: 82/100
# train size: 60 iteration: 83/100
# train size: 60 iteration: 84/100
# train size: 60 iteration: 85/100
# train size: 60 iteration: 86/100
# train size: 60 iteration: 87/100
# train size: 60 iteration: 88/100
# train size: 60 iteration: 89/100
# train size: 60 iteration: 90/100
# train size: 60 iteration: 91/100
# train size: 60 iteration: 92/100
# train size: 60 iteration: 93/100
# train size: 60 iteration: 94/100
# train size: 60 iteration: 95/100
# train size: 60 iteration: 96/100
# train size: 60 iteration: 97/100
# train size: 60 iteration: 98/100
# train size: 60 iteration: 99/100
# train size: 60 iteration: 100/100
# train size: 60 	mean acc: 90.656 	std: 4.425569341903932
# train size: 65 iteration: 1/100
# train size: 65 iteration: 2/100
# train size: 65 iteration: 3/100
# train size: 65 iteration: 4/100
# train size: 65 iteration: 5/100
# train size: 65 iteration: 6/100
# train size: 65 iteration: 7/100
# train size: 65 iteration: 8/100
# train size: 65 iteration: 9/100
# train size: 65 iteration: 10/100
# train size: 65 iteration: 11/100
# train size: 65 iteration: 12/100
# train size: 65 iteration: 13/100
# train size: 65 iteration: 14/100
# train size: 65 iteration: 15/100
# train size: 65 iteration: 16/100
# train size: 65 iteration: 17/100
# train size: 65 iteration: 18/100
# train size: 65 iteration: 19/100
# train size: 65 iteration: 20/100
# train size: 65 iteration: 21/100
# train size: 65 iteration: 22/100
# train size: 65 iteration: 23/100
# train size: 65 iteration: 24/100
# train size: 65 iteration: 25/100
# train size: 65 iteration: 26/100
# train size: 65 iteration: 27/100
# train size: 65 iteration: 28/100
# train size: 65 iteration: 29/100
# train size: 65 iteration: 30/100
# train size: 65 iteration: 31/100
# train size: 65 iteration: 32/100
# train size: 65 iteration: 33/100
# train size: 65 iteration: 34/100
# train size: 65 iteration: 35/100
# train size: 65 iteration: 36/100
# train size: 65 iteration: 37/100
# train size: 65 iteration: 38/100
# train size: 65 iteration: 39/100
# train size: 65 iteration: 40/100
# train size: 65 iteration: 41/100
# train size: 65 iteration: 42/100
# train size: 65 iteration: 43/100
# train size: 65 iteration: 44/100
# train size: 65 iteration: 45/100
# train size: 65 iteration: 46/100
# train size: 65 iteration: 47/100
# train size: 65 iteration: 48/100
# train size: 65 iteration: 49/100
# train size: 65 iteration: 50/100
# train size: 65 iteration: 51/100
# train size: 65 iteration: 52/100
# train size: 65 iteration: 53/100
# train size: 65 iteration: 54/100
# train size: 65 iteration: 55/100
# train size: 65 iteration: 56/100
# train size: 65 iteration: 57/100
# train size: 65 iteration: 58/100
# train size: 65 iteration: 59/100
# train size: 65 iteration: 60/100
# train size: 65 iteration: 61/100
# train size: 65 iteration: 62/100
# train size: 65 iteration: 63/100
# train size: 65 iteration: 64/100
# train size: 65 iteration: 65/100
# train size: 65 iteration: 66/100
# train size: 65 iteration: 67/100
# train size: 65 iteration: 68/100
# train size: 65 iteration: 69/100
# train size: 65 iteration: 70/100
# train size: 65 iteration: 71/100
# train size: 65 iteration: 72/100
# train size: 65 iteration: 73/100
# train size: 65 iteration: 74/100
# train size: 65 iteration: 75/100
# train size: 65 iteration: 76/100
# train size: 65 iteration: 77/100
# train size: 65 iteration: 78/100
# train size: 65 iteration: 79/100
# train size: 65 iteration: 80/100
# train size: 65 iteration: 81/100
# train size: 65 iteration: 82/100
# train size: 65 iteration: 83/100
# train size: 65 iteration: 84/100
# train size: 65 iteration: 85/100
# train size: 65 iteration: 86/100
# train size: 65 iteration: 87/100
# train size: 65 iteration: 88/100
# train size: 65 iteration: 89/100
# train size: 65 iteration: 90/100
# train size: 65 iteration: 91/100
# train size: 65 iteration: 92/100
# train size: 65 iteration: 93/100
# train size: 65 iteration: 94/100
# train size: 65 iteration: 95/100
# train size: 65 iteration: 96/100
# train size: 65 iteration: 97/100
# train size: 65 iteration: 98/100
# train size: 65 iteration: 99/100
# train size: 65 iteration: 100/100
# train size: 65 	mean acc: 91.172 	std: 4.378403361957415
# train size: 70 iteration: 1/100
# train size: 70 iteration: 2/100
# train size: 70 iteration: 3/100
# train size: 70 iteration: 4/100
# train size: 70 iteration: 5/100
# train size: 70 iteration: 6/100
# train size: 70 iteration: 7/100
# train size: 70 iteration: 8/100
# train size: 70 iteration: 9/100
# train size: 70 iteration: 10/100
# train size: 70 iteration: 11/100
# train size: 70 iteration: 12/100
# train size: 70 iteration: 13/100
# train size: 70 iteration: 14/100
# train size: 70 iteration: 15/100
# train size: 70 iteration: 16/100
# train size: 70 iteration: 17/100
# train size: 70 iteration: 18/100
# train size: 70 iteration: 19/100
# train size: 70 iteration: 20/100
# train size: 70 iteration: 21/100
# train size: 70 iteration: 22/100
# train size: 70 iteration: 23/100
# train size: 70 iteration: 24/100
# train size: 70 iteration: 25/100
# train size: 70 iteration: 26/100
# train size: 70 iteration: 27/100
# train size: 70 iteration: 28/100
# train size: 70 iteration: 29/100
# train size: 70 iteration: 30/100
# train size: 70 iteration: 31/100
# train size: 70 iteration: 32/100
# train size: 70 iteration: 33/100
# train size: 70 iteration: 34/100
# train size: 70 iteration: 35/100
# train size: 70 iteration: 36/100
# train size: 70 iteration: 37/100
# train size: 70 iteration: 38/100
# train size: 70 iteration: 39/100
# train size: 70 iteration: 40/100
# train size: 70 iteration: 41/100
# train size: 70 iteration: 42/100
# train size: 70 iteration: 43/100
# train size: 70 iteration: 44/100
# train size: 70 iteration: 45/100
# train size: 70 iteration: 46/100
# train size: 70 iteration: 47/100
# train size: 70 iteration: 48/100
# train size: 70 iteration: 49/100
# train size: 70 iteration: 50/100
# train size: 70 iteration: 51/100
# train size: 70 iteration: 52/100
# train size: 70 iteration: 53/100
# train size: 70 iteration: 54/100
# train size: 70 iteration: 55/100
# train size: 70 iteration: 56/100
# train size: 70 iteration: 57/100
# train size: 70 iteration: 58/100
# train size: 70 iteration: 59/100
# train size: 70 iteration: 60/100
# train size: 70 iteration: 61/100
# train size: 70 iteration: 62/100
# train size: 70 iteration: 63/100
# train size: 70 iteration: 64/100
# train size: 70 iteration: 65/100
# train size: 70 iteration: 66/100
# train size: 70 iteration: 67/100
# train size: 70 iteration: 68/100
# train size: 70 iteration: 69/100
# train size: 70 iteration: 70/100
# train size: 70 iteration: 71/100
# train size: 70 iteration: 72/100
# train size: 70 iteration: 73/100
# train size: 70 iteration: 74/100
# train size: 70 iteration: 75/100
# train size: 70 iteration: 76/100
# train size: 70 iteration: 77/100
# train size: 70 iteration: 78/100
# train size: 70 iteration: 79/100
# train size: 70 iteration: 80/100
# train size: 70 iteration: 81/100
# train size: 70 iteration: 82/100
# train size: 70 iteration: 83/100
# train size: 70 iteration: 84/100
# train size: 70 iteration: 85/100
# train size: 70 iteration: 86/100
# train size: 70 iteration: 87/100
# train size: 70 iteration: 88/100
# train size: 70 iteration: 89/100
# train size: 70 iteration: 90/100
# train size: 70 iteration: 91/100
# train size: 70 iteration: 92/100
# train size: 70 iteration: 93/100
# train size: 70 iteration: 94/100
# train size: 70 iteration: 95/100
# train size: 70 iteration: 96/100
# train size: 70 iteration: 97/100
# train size: 70 iteration: 98/100
# train size: 70 iteration: 99/100
# train size: 70 iteration: 100/100
# train size: 70 	mean acc: 90.714 	std: 4.477298739195319

# %%
# save the resulting curve
np.save('mean_accs.npy', np.array(val_acc_means))
np.save('std_accs.npy', np.array(val_acc_stds))

# %%
plt.figure()
plt.errorbar(train_sizes, val_acc_means, val_acc_stds)
plt.xlabel('training set size')
plt.ylabel('{} val repeats x {} train repeats'.format(val_its, train_its))
plt.title('3d-sift, GRU')
plt.savefig('rnn_accs.png')

# %%
# np.load('mean_accs.npy')
