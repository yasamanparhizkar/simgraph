# %%
import numpy as np
import scipy as sp
import cv2 as cv
import matplotlib.pyplot as plt
import time

# %% [markdown]
# # Download data

# %%
# Fetch MNIST dataset
from sklearn.datasets import fetch_openml

data_set = 'mnist'

if data_set == 'mnist':
    raw_data = fetch_openml('mnist_784')
    raw_data_x = np.array((raw_data['data']+0.5)/256.0)
    raw_data_y = np.array(raw_data['target'].astype('int8'))
    # separate classes 0 and 1 into a new dataset
    accptbl_cats = (raw_data_y == 0) | (raw_data_y == 1)
    
    raw_data_x = raw_data_x[accptbl_cats]
    raw_data_y = raw_data_y[accptbl_cats]
    num_classes = 2
    img_sz = (28,28)
else:
    assert False

data_dim = raw_data_x.shape[1]

# %% [markdown]
# ## Split data into training and validation

# %%
def display_image(x,lbl=None):
    plt.imshow(x.reshape(img_sz))
    plt.xticks([])
    plt.yticks([])
    if lbl is not None:
        plt.title(lbl)

def split_data(x,y,fracs=[0.8,0.2],seed=0):
    """
    Randomly splits data into two sets.

    Inputs: x, y, fracs=[0.8, 0.2], seed=0
    x - NxD matrix of x data (e.g. images)
    y - Nx1 vector of y data (e.g. labels)
    fracs - split fractions determining sizes of set one and set two.
    seed - random seed. 'None' disables the use of a new seed.

    Outputs: x1, y1, x2, y2
    x1 - (fracs[0]*N)xD matrix of x data of set 1
    y1 - (fracs[0]*N)x1 vector of y data of set 1
    x2 - (fracs[1]*N)xD matrix of x data of set 2
    y2 - (fracs[1]*N)x1 vector of y data of set 2
    """
    if seed is not None:
        np.random.seed(seed)
    N = x.shape[0]
    rp = np.random.permutation(N)

    N1 = int(fracs[0]*N)
    N2 = min(N-N1,int(fracs[1]*N))

    # Split the data into two parts
    x1 = x[rp[:N1]]
    y1 = y[rp[:N1]]
    x2 = x[rp[N1:(N1+N2)]]
    y2 = y[rp[N1:(N1+N2)]]

    return x1,y1,x2,y2

def onehot_encode(y,num_classes=10):
    """
    Convert an Nx1 vector of integer class labels from 0 to C-1 into 
    an NxC matrix where each row is a one-hot encoding of the 
    """
    return np.eye(num_classes)[y.reshape(-1)]

# %%
train_x,train_y,test_x,test_y = split_data(raw_data_x,raw_data_y,fracs=[0.005,0.005])
train_x,train_y,  val_x,val_y = split_data(train_x,train_y,fracs=[0.6,0.4])

# %%
print('num_train = ' + str(train_x.shape[0]))
print('num_val = ' + str(val_x.shape[0]))
print('num_test = ' + str(test_x.shape[0]))
print('num_classes = '+str(num_classes))
# Out:
# num_train = 43
# num_val = 29
# num_test = 73
# num_classes = 2

# %% [markdown]
# # Explore the data

# %%
# Print statistics
num_train = len(train_y)
for i in range(num_classes):
    num_class_i = np.sum(train_y == i)
    print('{:.2f}% of the training data is class {}, corresponding to {} data points'.format(100*num_class_i/num_train,
                                                                                       i, num_class_i))

# Visualize a few images
np.random.seed(0)
num_digits = 10
num_rows = 3
plt.figure(figsize=(10,5))
for i in range(num_rows*num_digits):
    ind = np.random.randint(0,train_x.shape[0])
    plt.subplot(num_rows,num_digits,i+1)
    display_image(train_x[ind,:],
                train_y[ind])
# Out:
# 37.21% of the training data is class 0, corresponding to 16 data points
# 62.79% of the training data is class 1, corresponding to 27 data points

# %% [markdown]
# # Implement activation and loss functions and their derivatives

# %%
def sigmoid(a,deriv=False):
    # The sigmoid activation function 1/(1+exp(-a)) and its derivative
    #
    # Input: a - NxC matrix of values where each row of a corresponds to a single
    # input to the current layer with C units.
    # Output: s,ds
    #   s - NxC matrix of sigmoid function evaluated at the values in a
    #  ds - NxC matrix of the derivatives of the sigmoid evaluated at the values of a
    #
    # NOTE: you may only use basic exp/log functions from numpy here.  Only
    # np.exp, np.log, np.log1p, np.log1m, along with basic arithmetic are allowed
    # in your implementation.

    s  = 1/(1.0 + np.exp(-a))

    if deriv:
        ns = 1/(1.0 + np.exp( a))
        ds = s*ns

        return s, ds
    else:
        return s

def relu(a,deriv=False):
    # TODO: Implement the relu activation function max(a,0) and its derivative
    #
    # Input: a - NxC matrix of values where each row of a corresponds to a single
    # input to the current layer with C units.
    # Output: r,dr
    #   r - NxC matrix of function values at the values in a
    #  dr - NxC matrix of the derivatives of the relu evaluated at the values of a

    r = np.maximum(a,0)
    if deriv:
        dr = (r == a)*1

        return r, dr
    else:
        return r

def softmax(a,params=None,deriv=False):
    # TODO: Implement the softmax function s = exp(a)/sum(exp(a)) and its
    # Jacobian where J[i,j] = ds[i]/da[j] = -(s[i]*s[j]) if i!=j and
    # (s[i]*(1-s[i])) if i==j.
    #
    # Input: a - NxC matrix of values where each row of a corresponds to a single
    # input to the softmax function
    # Output: s,ds
    #   s - NxC matrix of softmax function values at the values in a
    #  ds - NxCxC tensor of Jacobians of the softmax function of each input

    N,C = a.shape

    c = np.amax(a,1).reshape(N,1)
    s = np.exp(a-c)/np.sum(np.exp(a-c), 1).reshape(N,1)
    if deriv:
        ds = np.array([np.diag(s[i]) - np.outer(s[i],s[i]) for i in range(N)]) # NEEDS BETTER EFFICIENCY!!!!!!!

        return s, ds
    else:
        return s

def identity(a,deriv=False):
    if deriv:
        return a, np.ones_like(a)
    else:
        return a

def crossent(y,yhat,deriv=False):
    # TODO: Implement the cross entropy loss L = -\sum_c (y==c) log(p(y==c)).
    #
    # Input: y,yhat
    #     y - Nx1 vector of class labels for N inputs
    #  yhat - NxC matrix of probabilities of each class c for each input i
    #         i.e., yhat[i,c] is p(y[i]==c)
    #
    # Output: l,dl
    #   l - Nx1 vector of cross entropy values
    #  dl - Nx1xC matrix of derivatives
    N,C = yhat.shape
    assert y.shape[0] == N

    p_correctlbl = (yhat[np.arange(N), y]).reshape(N,1)
    l = -np.log(p_correctlbl)
    if deriv:
        dl = onehot_encode(y, num_classes)*(-1/p_correctlbl)
        dl.reshape(N,1,C)

        return l,dl
    else:
        return l

def test_acts_impl():
    # These are sanity checks, not exhaustive unit tests.  These may pass but you
    # may still have bugs.  However, if these don't pass you almost certainly have
    # bugs.

    import scipy.special as spsp

    acts = [sigmoid,relu,softmax,identity]
    N = 2
    D = 5
    eps = 1e-8
    for _ in range(5):
        aval0 = np.random.randn(N,D)
        for afunc in acts:
            fval, dfval = afunc(aval0,deriv=True)
            # print(afunc) # uncomment this line to see which activation function is failing
            for i in range(D):
                aval_m = np.copy(aval0)
                aval_m[:,i] -= eps
                aval_p = np.copy(aval0)
                aval_p[:,i] += eps

            dfval_fd = (afunc(aval_p) - afunc(aval_m))/(2*eps)
            if dfval.ndim == 3:
                assert np.allclose(dfval_fd,dfval[:,:,i])
            else:
                assert np.allclose(dfval_fd[:,i],dfval[:,i])

    # unit test the sigmoid function
    eps = 1e-8
    avals = [-5,0.1,1]
    for a in avals:
        sa = sigmoid(a)

    assert np.all(sa > 0)
    assert np.all(sa < 1)
    assert np.abs(sa - spsp.expit(a)) < 1e-8

    # unit test the softmax function
    N = 2
    D = 5
    eps = 1e-8
    logitval0 = np.random.randn(N,D)
    s0 = softmax(logitval0)
    assert np.all(s0 >= 0)
    assert np.all(np.abs(1-np.sum(s0,axis=1))<1e-8)


    ina = np.linspace(-10,10,1000)
    plt.figure()
    plt.subplot(1,2,1)
    plt.plot(ina,sigmoid(ina,deriv=False))
    plt.title('$\sigma(a)$')
    plt.subplot(1,2,2)
    plt.plot(ina,sigmoid(ina,deriv=True)[1])
    plt.title('$d \sigma(a)$')

    ina = np.linspace(-10,10,1000)
    plt.figure()
    plt.subplot(1,2,1)
    plt.plot(ina,relu(ina,deriv=False))
    plt.title('$relu(a)$')
    plt.subplot(1,2,2)
    plt.plot(ina,relu(ina,deriv=True)[1])
    plt.title('$d relu(a)$')

test_acts_impl()

# %% [markdown]
# # Implement forward pass and backprop

# %%
def nn_forward(x,acts,Theta):
    """
    Compute the forward pass of a neural network model for a set of inputs.

    Input: x,loss,acts,Theta,deriv
    x - NxD matrix of input vectors
    acts - list of length L of activation functions for each layer
    Theta - list of length L of the parameters of each layer.  In general, 
            Theta[i] = (Wi,bi) where Wi and bi are the weight matrix and bias 
            vector for layer i.

    Output: z
    z - an NxC matrix where C is the dimensionality of the output
    """
    N = x.shape[0]
    num_layers = len(acts)
    z = x

    for i in range(num_layers):
        act = acts[i] # activation function at this layer
        Wi,bi = Theta[i] # parameters at this layer 

        ai = (Wi @ z.T + bi).T
        z = act(ai,deriv=False)

    return z

def nn_loss(x,y,loss,acts,Theta,deriv=False):
    """
    Compute the objective function (and gradients) of the loss function for a set
    of data using a neural network model.

    Input: x,y,loss,acts,Theta,deriv
    x - NxD matrix of input vectors
    y - Nx1 vector of ground truth labels
    loss - function handle for the loss function
    acts - list of length L of activation functions for each layer
    Theta - list of length L of the parameters of each layer.  In general, 
            Theta[i] = (Wi,bi) where Wi and bi are the weight matrix and bias 
            vector for layer i.
    deriv - whether or not to compute and do the derivative

    Output: if deriv: E, dEdTheta, acc
              else: E, acc
    E - value of the loss function
    dEdTheta - the derivatives of the loss function for the parameters in Theta
               it has the same layout as Theta, specifically, 
                 dEdTheta[i] = (dEdWi,dEdbi) is the
               derivative of E with respect to the weight matrix and bias vector
               of layer i.
    acc - accuracy of predictions on the given data
    """
    N = x.shape[0]
    num_layers = len(acts)
    z = x

    zs = [] # input and output of each layer
    dzi_dais = [] # derivative of activation function of each layer
    for i in range(num_layers):
        act = acts[i] # activation function at this layer
        Wi,bi = Theta[i] # parameters at this layer 

        ai = (Wi @ z.T + bi).T
        if deriv:
            zs.append(z) # store input to the layer, needed for derivative wrt W

            z, dzi_dai = act(ai,deriv=True)
            dzi_dais.append(dzi_dai) # store derivative of activation function
        else:
            z = act(ai,deriv=False)

    maxc = np.argmax(z,axis=1) # Index of class with maximum probability
    acc = np.sum(maxc == y)/N

    if deriv:
        L, dLdz = loss(y,z,deriv=True)
        E = np.mean(L)

        dEdTheta = [None]*len(acts)

        # Initialize backprop with the gradients of the loss values wrt to the
        # output of the last layer
        # 
        # dLdzi has shape Nx1xDi where Di is the dimensionality of layer i because
        # we are treating it as the Jacobian of a function with 1 output
        dLdzi = (1.0/N)*dLdz

        # Backward pass
        for i in reversed(range(num_layers)):
            act = acts[i] # activation function at this layer
            Wi,bi = Theta[i] # parameters at this layer 
            zi_1 = zs[i] # input to the current layer
            dzi_dai = dzi_dais[i] # derivatives of layer activation function

            Di, Di_1 = Wi.shape
            # TODO: Backpropogate the derivative dLdzi through the activation function 
            # to compute dLdai.
            if dzi_dai.ndim == 2:
                # If dzi_dai only has two dimensions, then this activation function is 
                # element wise, so we only need to multiply each element of dLdzi with
                # it's corresponding derivative in dzi_dai.
                dLdai = (dLdzi * dzi_dai).reshape(N,1,Di)
            else:
                # If dzi_dai only has three dimensions, then this activation function is 
                # not elementwise and has a full Jacobian so we need to multiply the
                # jacobians dLzi[i] (a 1xDi matrix) and dzi_dai[i] (a DixDi matrix) for
                # each data point i.  For efficiency try to avoid looping by using the
                # @ operator and/or the np.matmul function.
                dLdai = (dLdzi.reshape(N,1,Di)) @ dzi_dai

            # TODO: Backpropogate the derivative dLdai through the linear
            # transformation to compute dLdzi for the next layer.
            dLdzi = (dLdai @ Wi).reshape(N,Di_1)

            # Derivatives of the parameters of the linear layer
            dEdW = np.sum(dLdai.reshape((N,Di,1)) * zi_1.reshape((N,1,Di_1)),axis=0)
            dEdb = np.sum(dLdai.reshape((N,Di)),axis=0).reshape((Di,1))
            dEdTheta[i] = (dEdW,dEdb)

        return E, dEdTheta, acc
    else:
        L = loss(y,z,deriv=False)
        E = np.mean(L)
        return E, acc

# %% [markdown]
# ## Implement network training with GD

# %%
def nn_fit(train_x, train_y, val_x, val_y,
           opt_params, arch_params):
    """
    Train a neural network using gradient descent.

    Inputs: train_x, train_y, val_x, val_y, opt_params, arch_params
    train_x - NxD matrix of full training set with N samples and D dimensions
    train_y - Nx1 vector of training output values
    val_x, val_y - a validation set of samples to monitor performance
    opt_params - parameters of the training algorithm (see below)
    arch_params - parameters of the neural network architecture (see below)

    Outputs: Theta, stats
    Theta - parameters at the end of optimization
    stats - dictionary of various statistics computed during training to be used
            for visualization and analysis
    """

    # Optimization parameters in opt_params
    epsilon0 = opt_params['epsilon0'] # starting learning rate for GD
    epsilon_decay = opt_params['epsilon_decay'] # decay factor for GD learning rate
    epsilon_jump = opt_params['epsilon_jump'] # decay factor for GD learning rate
    num_its = opt_params['num_its'] # number of iterations to run
    Theta0 = opt_params['Theta0'] # initial value for the parameters, can be None to randomly initialize
    check_freq = opt_params['check_freq'] # how frequently to compute and print out statistics of learning
    print_checks = opt_params['print_checks'] # print info out when checkpointing
    seed = opt_params['seed'] if 'seed' in opt_params else 0

    if seed is not None:
        np.random.seed(seed)

    # Neural Network architecture parameters in arch_params
    num_hidden_layers = arch_params['num_hidden_layers'] # number of hidden layers
    num_hidden_units = arch_params['num_hidden_units'] # number of units per hidden layer (all layers are assumed to have the same number)
    num_outs = arch_params['num_outs'] # number of outputs, for classification the number of classes
    act_func = arch_params['act_func'] # hidden layer activation function
    out_func = arch_params['out_func'] # output layer activation function
    loss_func = arch_params['loss_func'] # loss function to use for training

    train_N, data_dim = train_x.shape

    assert num_hidden_layers >= 0
    acts = [act_func]*num_hidden_layers + [out_func]
    if Theta0 is None:
        # If no initial value of parameters is given, this randomly generates one.
        if num_hidden_layers > 1:
            Theta0 = [    (0.1*np.random.randn(num_hidden_units,data_dim),      np.zeros((num_hidden_units,1))) ] + \
                   [ (0.1*np.random.randn(num_hidden_units,num_hidden_units), np.zeros((num_hidden_units,1))) ]*(num_hidden_layers-1) + \
                   [    (0.1*np.random.randn(num_outs,num_hidden_units),              np.zeros((num_outs,1))) ]
        elif num_hidden_layers == 1:
            Theta0 = [ (0.1*np.random.randn(num_hidden_units,data_dim), np.zeros((num_hidden_units,1))) ] + \
                   [ (0.1*np.random.randn(num_outs,num_hidden_units),         np.zeros((num_outs,1))) ]
        elif num_hidden_layers == 0:
            Theta0 = [ (0.1*np.random.randn(num_outs,data_dim),   np.zeros((num_outs,1))) ]

    check_its = []
    check_times = []
    it_times = []
    data_pts = []
    check_data_pts = []
    check_Thetas = []
    train_losss = []
    train_accs = []
    val_losss = []
    val_accs = []
    epsilon = epsilon0
    start_t = time.time()
    num_data_proc = 0
    Theta = Theta0
    for it in range(num_its):
        # Compute loss and its derivative with current parameter values
        train_loss, dEdTheta, train_acc = nn_loss(train_x,train_y,loss_func,acts,Theta,deriv=True)
        num_data_proc += train_N

        # Find epsilon which decreases train loss
        epsilon *= epsilon_jump
        new_train_loss = np.inf
        while new_train_loss > train_loss:
            nrmsq_dEdTheta = 0
            Theta1 = []
            # Loop over all layers and update their parameters with the GD update
            for (Wi,bi),(dEdWi,dEdbi) in zip(Theta,dEdTheta):
                # TODO: Wi1 and bi1 should be the value of the parameters after the
                # gradient update based on the derivatives dEdWi,dEdbi, previous
                # parameter values Wi,bi and stepsize epsilon
                Wi1 = Wi - epsilon * dEdWi
                bi1 = bi - epsilon * dEdbi

                Theta1.append((Wi1,bi1))

                # Compute the norm of the entire gradient to monitor
                nrmsq_dEdTheta += np.sum(dEdWi**2) + np.sum(dEdbi**2)
            
            new_train_loss, new_train_acc = nn_loss(train_x,train_y,loss_func,acts,Theta,deriv=False)
            epsilon *= epsilon_decay

        # Replace old value of Theta with new one
        Theta = Theta1
        

        if it%check_freq == 0 or it+1 == num_its:
            # Periodically compute the training loss/accuracy on the _full_ dataset
            # for reference.  Note this is rarely done in practice because it isn't
            # possible or is hugely impractical.  We're just doing it here to see 
            # how it relates to the values computed with a mini-batch
            train_loss, train_acc = nn_loss(train_x,train_y,
                                       loss_func,acts,Theta,deriv=False)


            # Periodically compute the validation loss/accuracy for reference.
            val_loss, val_acc = nn_loss(val_x,val_y,
                                   loss_func,acts,Theta,deriv=False)

            check_Thetas.append(Theta)
            check_its.append(it)
            check_data_pts.append(num_data_proc)
            check_times.append(time.time() - start_t)
            train_losss.append(train_loss)
            train_accs.append(train_acc)
            val_losss.append(val_loss)
            val_accs.append(val_acc)
            if print_checks:
                print("{:4}: eps = {:.2e};"
                      "  train: loss = {:5.2f}, acc = {:.2f};"
                      "  val: loss = {:5.2f}, acc = {:.2f};"
                      "  ||dEdTheta|| = {:5.2f}".format(it, epsilon,
                                                        train_loss, train_acc,
                                                        val_loss, val_acc,
                                                        np.sqrt(nrmsq_dEdTheta)))
        data_pts.append(num_data_proc)
        it_times.append(time.time() - start_t)

    stats = { 'check_its':check_its, # Iteration numbers of checkpoints
            'check_times':check_times, # wall clock time of checkpoints
            'check_data_pts':check_data_pts, # number of training samples processed at check points
            'check_Thetas':check_Thetas, # Theta values at checkpoints
            'it_times':it_times, # wall clock time of each iteration
            'data_pts':data_pts, # number of training samples processed at each iteration
            'train_losss':train_losss, 'train_accs':train_accs, # loss and accuracy of full training set at checkpoint iterations
            'val_losss':val_losss, 'val_accs':val_accs } # loss and accuracy of validation set at checkpoint iterations
    return Theta, stats

# %% [markdown]
# ## Train a network on the dataset

# %%
opt_params = { 'epsilon0':1, 'epsilon_decay':0.5, 'epsilon_jump': 1.5,
               'num_its':10, 'check_freq':1, 'print_checks':True, 'Theta0':None, 'seed':None }
arch_params = { 'num_hidden_layers':1, 'num_hidden_units':5, 'num_outs':num_classes,
                'act_func':relu, 'out_func':softmax, 'loss_func':crossent }

Theta, stats = nn_fit(train_x, train_y, val_x, val_y,
                      opt_params, arch_params)
# Out:
#    0: eps = 7.50e-01;  train: loss =  0.00, acc = 1.00;  val: loss =  0.03, acc = 1.00;  ||dEdTheta|| =  2.88
#    1: eps = 5.62e-01;  train: loss =  0.00, acc = 1.00;  val: loss =  0.03, acc = 1.00;  ||dEdTheta|| =  0.01
#    2: eps = 4.22e-01;  train: loss =  0.00, acc = 1.00;  val: loss =  0.03, acc = 1.00;  ||dEdTheta|| =  0.01
#    3: eps = 3.16e-01;  train: loss =  0.00, acc = 1.00;  val: loss =  0.02, acc = 1.00;  ||dEdTheta|| =  0.01
#    4: eps = 2.37e-01;  train: loss =  0.00, acc = 1.00;  val: loss =  0.02, acc = 1.00;  ||dEdTheta|| =  0.01
#    5: eps = 1.78e-01;  train: loss =  0.00, acc = 1.00;  val: loss =  0.02, acc = 1.00;  ||dEdTheta|| =  0.01
#    6: eps = 1.33e-01;  train: loss =  0.00, acc = 1.00;  val: loss =  0.02, acc = 1.00;  ||dEdTheta|| =  0.01
#    7: eps = 1.00e-01;  train: loss =  0.00, acc = 1.00;  val: loss =  0.02, acc = 1.00;  ||dEdTheta|| =  0.01
#    8: eps = 7.51e-02;  train: loss =  0.00, acc = 1.00;  val: loss =  0.02, acc = 1.00;  ||dEdTheta|| =  0.01
#    9: eps = 5.63e-02;  train: loss =  0.00, acc = 1.00;  val: loss =  0.02, acc = 1.00;  ||dEdTheta|| =  0.01

# %%
print('final validation accuracy is {:.6f}'.format(stats['val_accs'][-1]))
# Out:
# final validation accuracy is 1.000000

# %% [markdown]
# ## Visualize the training process with some plots

# %%
plt.figure(figsize=(10,5))
plt.plot(stats['check_its'],stats['train_losss'],label='train loss')
plt.plot(stats['check_its'],stats['val_losss'],label='val loss')
plt.xlabel('Iterations')
plt.legend()

plt.figure(figsize=(10,5))
plt.plot(stats['check_its'],stats['train_accs'],label='train acc')
plt.plot(stats['check_its'],stats['val_accs'],label='val acc')
plt.xlabel('Iterations')
plt.legend()

# %% [markdown]
# # Try out different sizes

# %%
def learn_nn(raw_data_x, raw_data_y, portion, fracs, img_sz=(28,28), num_classes=2, show_msgs=False):
    """
    Receive downloaded mnist data as input.
    Randomly select a specific portion of the data and split it into training and validation datasets.
    Fit a simple one-layer neural network to training data via gradient descent.
    (Refer to the code for details of nn's architecture.)
    Calculate accuracy using the validation data.
    
    Inputs: raw_data_x, raw_data_y, portion, fracs, img_sz, num_classes, show_msgs
    raw_data_x - NtxD tensor of raw input images to be classified into two classes
    raw_data_y - Ntx1 vector of corresponding labels for images; described as 0 and 1
    portion - the portion of raw data to be used in the algorithm (whole dataset might be too large)
    fracs - fractions of split between training and validation data (e.g. [0.6, 0.4])
    
    Outputs: num_train, num_val, acc, Theta
    num_train - number of training images
    num_val - number of validation images
    acc - accuracy obtained on validation set
    Theta - final optimized parameters of the neural network
    """
    
    # split data into training and validation datasets
    train_x,train_y,test_x,test_y = split_data(raw_data_x,raw_data_y,fracs=[portion,portion],seed=None)
    train_x,train_y,  val_x,val_y = split_data(train_x,train_y,fracs=fracs,seed=None)
    
    # define number of training and validation images
    num_train = len(train_y)
    num_val = len(val_y)
    
    # define gradient descent parameters
    opt_params = { 'epsilon0':1, 'epsilon_decay':0.5, 'epsilon_jump': 1.5,
               'num_its':10, 'check_freq':1, 'print_checks':show_msgs, 'Theta0':None, 'seed':None }
    
    # define neural network architecture
    arch_params = { 'num_hidden_layers':1, 'num_hidden_units':5, 'num_outs':num_classes,
                    'act_func':relu, 'out_func':softmax, 'loss_func':crossent }

    # fit neural network to the training images and measure accuracy on validation set
    Theta, stats = nn_fit(train_x, train_y, val_x, val_y, opt_params, arch_params)
    
    # accuracy obtained in the final iteration of gradient descent
    acc = stats['val_accs'][-1]
    
    return num_train, num_val, acc, Theta

# %%
portions = [0.005, 0.01, 0.015, 0.02]
#portions = [0.005, 0.01, 0.015, 0.02, 0.025, 0.03]
rpt = 10000

x = []
y = []
x_err = []
y_err = []

for portion in portions:
    accs = []
    num_vals = []
    for i in range(rpt):
        _, num_val1, acc1, _ = learn_nn(raw_data_x, raw_data_y, portion=portion, fracs=[0.6, 0.4], \
                                        num_classes=num_classes, show_msgs=False)
        print('portion = {} #{}:\tnum_val = {}\tacc = {:.6f}'.format(portion, i, num_val1, acc1))
        accs.append(acc1)
        num_vals.append(num_val1)
        
    x.append(np.mean(num_vals))
    x_err.append(np.std(num_vals))
    y.append(np.mean(accs))
    y_err.append(np.std(accs))
    print('FIN portion = {}:\tnum_val = {:.6f} +- {:.6f}\tacc = {:.6f} +- {:.6f}'.format(portion, np.mean(num_vals), np.std(num_vals), np.mean(accs), np.std(accs)))
# Out:
# portion = 0.005 #0:	num_val = 29	acc = 1.000000
# portion = 0.005 #1:	num_val = 29	acc = 0.965517
# portion = 0.005 #2:	num_val = 29	acc = 1.000000
# portion = 0.005 #3:	num_val = 29	acc = 1.000000
# portion = 0.005 #4:	num_val = 29	acc = 1.000000
# portion = 0.005 #5:	num_val = 29	acc = 1.000000
# portion = 0.005 #6:	num_val = 29	acc = 1.000000
# portion = 0.005 #7:	num_val = 29	acc = 0.965517
# portion = 0.005 #8:	num_val = 29	acc = 0.931034
# portion = 0.005 #9:	num_val = 29	acc = 0.965517
# portion = 0.005 #10:	num_val = 29	acc = 0.965517
# portion = 0.005 #11:	num_val = 29	acc = 1.000000
# portion = 0.005 #12:	num_val = 29	acc = 1.000000
# portion = 0.005 #13:	num_val = 29	acc = 1.000000
# portion = 0.005 #14:	num_val = 29	acc = 1.000000
# portion = 0.005 #15:	num_val = 29	acc = 1.000000
# portion = 0.005 #16:	num_val = 29	acc = 0.413793
# portion = 0.005 #17:	num_val = 29	acc = 0.965517
# portion = 0.005 #18:	num_val = 29	acc = 0.965517
# portion = 0.005 #19:	num_val = 29	acc = 1.000000
# portion = 0.005 #20:	num_val = 29	acc = 1.000000
# portion = 0.005 #21:	num_val = 29	acc = 1.000000
# portion = 0.005 #22:	num_val = 29	acc = 1.000000
# portion = 0.005 #23:	num_val = 29	acc = 1.000000
# portion = 0.005 #24:	num_val = 29	acc = 1.000000
# portion = 0.005 #25:	num_val = 29	acc = 1.000000
# portion = 0.005 #26:	num_val = 29	acc = 1.000000
# portion = 0.005 #27:	num_val = 29	acc = 1.000000
# portion = 0.005 #28:	num_val = 29	acc = 1.000000
# portion = 0.005 #29:	num_val = 29	acc = 1.000000
# portion = 0.005 #30:	num_val = 29	acc = 1.000000
# portion = 0.005 #31:	num_val = 29	acc = 1.000000
# portion = 0.005 #32:	num_val = 29	acc = 1.000000
# portion = 0.005 #33:	num_val = 29	acc = 1.000000
# portion = 0.005 #34:	num_val = 29	acc = 1.000000
# portion = 0.005 #35:	num_val = 29	acc = 1.000000
# portion = 0.005 #36:	num_val = 29	acc = 1.000000
# portion = 0.005 #37:	num_val = 29	acc = 1.000000
# portion = 0.005 #38:	num_val = 29	acc = 1.000000
# portion = 0.005 #39:	num_val = 29	acc = 1.000000
# portion = 0.005 #40:	num_val = 29	acc = 1.000000
# portion = 0.005 #41:	num_val = 29	acc = 0.965517
# portion = 0.005 #42:	num_val = 29	acc = 0.965517
# portion = 0.005 #43:	num_val = 29	acc = 1.000000
# portion = 0.005 #44:	num_val = 29	acc = 1.000000
# portion = 0.005 #45:	num_val = 29	acc = 0.965517
# portion = 0.005 #46:	num_val = 29	acc = 1.000000
# portion = 0.005 #47:	num_val = 29	acc = 1.000000
# portion = 0.005 #48:	num_val = 29	acc = 1.000000
# portion = 0.005 #49:	num_val = 29	acc = 0.965517
# portion = 0.005 #50:	num_val = 29	acc = 1.000000
# portion = 0.005 #51:	num_val = 29	acc = 0.965517
# portion = 0.005 #52:	num_val = 29	acc = 0.896552
# portion = 0.005 #53:	num_val = 29	acc = 1.000000
# portion = 0.005 #54:	num_val = 29	acc = 1.000000
# portion = 0.005 #55:	num_val = 29	acc = 1.000000
# portion = 0.005 #56:	num_val = 29	acc = 1.000000
# portion = 0.005 #57:	num_val = 29	acc = 0.965517
# portion = 0.005 #58:	num_val = 29	acc = 1.000000
# portion = 0.005 #59:	num_val = 29	acc = 1.000000
# portion = 0.005 #60:	num_val = 29	acc = 1.000000
# portion = 0.005 #61:	num_val = 29	acc = 1.000000
# portion = 0.005 #62:	num_val = 29	acc = 0.931034
# portion = 0.005 #63:	num_val = 29	acc = 1.000000
# portion = 0.005 #64:	num_val = 29	acc = 1.000000
# portion = 0.005 #65:	num_val = 29	acc = 1.000000
# portion = 0.005 #66:	num_val = 29	acc = 1.000000
# portion = 0.005 #67:	num_val = 29	acc = 1.000000
# portion = 0.005 #68:	num_val = 29	acc = 1.000000
# portion = 0.005 #69:	num_val = 29	acc = 1.000000
# portion = 0.005 #70:	num_val = 29	acc = 1.000000
# portion = 0.005 #71:	num_val = 29	acc = 1.000000
# portion = 0.005 #72:	num_val = 29	acc = 0.965517
# portion = 0.005 #73:	num_val = 29	acc = 0.551724
# portion = 0.005 #74:	num_val = 29	acc = 1.000000
# portion = 0.005 #75:	num_val = 29	acc = 0.965517
# portion = 0.005 #76:	num_val = 29	acc = 1.000000
# portion = 0.005 #77:	num_val = 29	acc = 1.000000
# portion = 0.005 #78:	num_val = 29	acc = 1.000000
# portion = 0.005 #79:	num_val = 29	acc = 0.931034
# portion = 0.005 #80:	num_val = 29	acc = 0.965517
# portion = 0.005 #81:	num_val = 29	acc = 0.310345
# portion = 0.005 #82:	num_val = 29	acc = 1.000000
# portion = 0.005 #83:	num_val = 29	acc = 1.000000
# portion = 0.005 #84:	num_val = 29	acc = 1.000000
# portion = 0.005 #85:	num_val = 29	acc = 1.000000
# portion = 0.005 #86:	num_val = 29	acc = 1.000000
# portion = 0.005 #87:	num_val = 29	acc = 1.000000
# portion = 0.005 #88:	num_val = 29	acc = 1.000000
# portion = 0.005 #89:	num_val = 29	acc = 1.000000
# portion = 0.005 #90:	num_val = 29	acc = 0.965517
# portion = 0.005 #91:	num_val = 29	acc = 1.000000
# portion = 0.005 #92:	num_val = 29	acc = 1.000000
# portion = 0.005 #93:	num_val = 29	acc = 1.000000
# portion = 0.005 #94:	num_val = 29	acc = 0.965517
# portion = 0.005 #95:	num_val = 29	acc = 0.931034
# portion = 0.005 #96:	num_val = 29	acc = 1.000000
# portion = 0.005 #97:	num_val = 29	acc = 1.000000
# portion = 0.005 #98:	num_val = 29	acc = 0.965517
# portion = 0.005 #99:	num_val = 29	acc = 0.965517
# portion = 0.005 #100:	num_val = 29	acc = 1.000000
# portion = 0.005 #101:	num_val = 29	acc = 0.896552
# portion = 0.005 #102:	num_val = 29	acc = 1.000000
# portion = 0.005 #103:	num_val = 29	acc = 0.965517
# portion = 0.005 #104:	num_val = 29	acc = 0.965517
# portion = 0.005 #105:	num_val = 29	acc = 1.000000
# portion = 0.005 #106:	num_val = 29	acc = 0.965517
# portion = 0.005 #107:	num_val = 29	acc = 1.000000
# portion = 0.005 #108:	num_val = 29	acc = 0.965517
# portion = 0.005 #109:	num_val = 29	acc = 1.000000
# portion = 0.005 #110:	num_val = 29	acc = 1.000000
# portion = 0.005 #111:	num_val = 29	acc = 1.000000
# portion = 0.005 #112:	num_val = 29	acc = 1.000000
# portion = 0.005 #113:	num_val = 29	acc = 1.000000
# portion = 0.005 #114:	num_val = 29	acc = 1.000000
# portion = 0.005 #115:	num_val = 29	acc = 1.000000
# portion = 0.005 #116:	num_val = 29	acc = 1.000000
# portion = 0.005 #117:	num_val = 29	acc = 1.000000
# portion = 0.005 #118:	num_val = 29	acc = 1.000000
# portion = 0.005 #119:	num_val = 29	acc = 0.965517
# portion = 0.005 #120:	num_val = 29	acc = 1.000000
# portion = 0.005 #121:	num_val = 29	acc = 1.000000
# portion = 0.005 #122:	num_val = 29	acc = 0.965517
# portion = 0.005 #123:	num_val = 29	acc = 1.000000
# portion = 0.005 #124:	num_val = 29	acc = 0.586207
# portion = 0.005 #125:	num_val = 29	acc = 1.000000
# portion = 0.005 #126:	num_val = 29	acc = 0.896552
# portion = 0.005 #127:	num_val = 29	acc = 1.000000
# portion = 0.005 #128:	num_val = 29	acc = 1.000000
# portion = 0.005 #129:	num_val = 29	acc = 1.000000
# portion = 0.005 #130:	num_val = 29	acc = 1.000000
# portion = 0.005 #131:	num_val = 29	acc = 1.000000
# portion = 0.005 #132:	num_val = 29	acc = 1.000000
# portion = 0.005 #133:	num_val = 29	acc = 1.000000
# portion = 0.005 #134:	num_val = 29	acc = 1.000000
# portion = 0.005 #135:	num_val = 29	acc = 1.000000
# portion = 0.005 #136:	num_val = 29	acc = 1.000000
# portion = 0.005 #137:	num_val = 29	acc = 0.931034
# portion = 0.005 #138:	num_val = 29	acc = 1.000000
# portion = 0.005 #139:	num_val = 29	acc = 1.000000
# portion = 0.005 #140:	num_val = 29	acc = 1.000000
# portion = 0.005 #141:	num_val = 29	acc = 1.000000
# portion = 0.005 #142:	num_val = 29	acc = 1.000000
# portion = 0.005 #143:	num_val = 29	acc = 0.965517
# portion = 0.005 #144:	num_val = 29	acc = 1.000000
# portion = 0.005 #145:	num_val = 29	acc = 1.000000
# portion = 0.005 #146:	num_val = 29	acc = 1.000000
# portion = 0.005 #147:	num_val = 29	acc = 0.965517
# portion = 0.005 #148:	num_val = 29	acc = 0.931034
# portion = 0.005 #149:	num_val = 29	acc = 0.965517
# portion = 0.005 #150:	num_val = 29	acc = 0.827586
# portion = 0.005 #151:	num_val = 29	acc = 0.965517
# portion = 0.005 #152:	num_val = 29	acc = 1.000000
# portion = 0.005 #153:	num_val = 29	acc = 1.000000
# portion = 0.005 #154:	num_val = 29	acc = 1.000000
# portion = 0.005 #155:	num_val = 29	acc = 1.000000
# portion = 0.005 #156:	num_val = 29	acc = 1.000000
# portion = 0.005 #157:	num_val = 29	acc = 1.000000
# portion = 0.005 #158:	num_val = 29	acc = 0.965517
# portion = 0.005 #159:	num_val = 29	acc = 1.000000
# portion = 0.005 #160:	num_val = 29	acc = 1.000000
# portion = 0.005 #161:	num_val = 29	acc = 1.000000
# portion = 0.005 #162:	num_val = 29	acc = 1.000000
# portion = 0.005 #163:	num_val = 29	acc = 1.000000
# portion = 0.005 #164:	num_val = 29	acc = 1.000000
# portion = 0.005 #165:	num_val = 29	acc = 0.931034
# portion = 0.005 #166:	num_val = 29	acc = 1.000000
# portion = 0.005 #167:	num_val = 29	acc = 0.965517
# portion = 0.005 #168:	num_val = 29	acc = 0.965517
# portion = 0.005 #169:	num_val = 29	acc = 1.000000
# portion = 0.005 #170:	num_val = 29	acc = 0.931034
# portion = 0.005 #171:	num_val = 29	acc = 1.000000
# portion = 0.005 #172:	num_val = 29	acc = 0.965517
# portion = 0.005 #173:	num_val = 29	acc = 0.965517
# portion = 0.005 #174:	num_val = 29	acc = 1.000000
# portion = 0.005 #175:	num_val = 29	acc = 1.000000
# portion = 0.005 #176:	num_val = 29	acc = 1.000000
# portion = 0.005 #177:	num_val = 29	acc = 1.000000
# portion = 0.005 #178:	num_val = 29	acc = 1.000000
# portion = 0.005 #179:	num_val = 29	acc = 1.000000
# portion = 0.005 #180:	num_val = 29	acc = 1.000000
# portion = 0.005 #181:	num_val = 29	acc = 0.517241
# portion = 0.005 #182:	num_val = 29	acc = 0.931034
# portion = 0.005 #183:	num_val = 29	acc = 0.965517
# portion = 0.005 #184:	num_val = 29	acc = 1.000000
# portion = 0.005 #185:	num_val = 29	acc = 0.965517
# portion = 0.005 #186:	num_val = 29	acc = 1.000000
# portion = 0.005 #187:	num_val = 29	acc = 1.000000
# portion = 0.005 #188:	num_val = 29	acc = 0.965517
# portion = 0.005 #189:	num_val = 29	acc = 1.000000
# portion = 0.005 #190:	num_val = 29	acc = 1.000000
# portion = 0.005 #191:	num_val = 29	acc = 1.000000
# portion = 0.005 #192:	num_val = 29	acc = 1.000000
# portion = 0.005 #193:	num_val = 29	acc = 1.000000
# portion = 0.005 #194:	num_val = 29	acc = 0.965517
# portion = 0.005 #195:	num_val = 29	acc = 1.000000
# portion = 0.005 #196:	num_val = 29	acc = 1.000000
# portion = 0.005 #197:	num_val = 29	acc = 0.965517
# portion = 0.005 #198:	num_val = 29	acc = 1.000000
# portion = 0.005 #199:	num_val = 29	acc = 1.000000
# portion = 0.005 #200:	num_val = 29	acc = 1.000000
# portion = 0.005 #201:	num_val = 29	acc = 0.896552
# portion = 0.005 #202:	num_val = 29	acc = 0.965517
# portion = 0.005 #203:	num_val = 29	acc = 1.000000
# portion = 0.005 #204:	num_val = 29	acc = 0.965517
# portion = 0.005 #205:	num_val = 29	acc = 1.000000
# portion = 0.005 #206:	num_val = 29	acc = 1.000000
# portion = 0.005 #207:	num_val = 29	acc = 0.965517
# portion = 0.005 #208:	num_val = 29	acc = 1.000000
# portion = 0.005 #209:	num_val = 29	acc = 0.965517
# portion = 0.005 #210:	num_val = 29	acc = 1.000000
# portion = 0.005 #211:	num_val = 29	acc = 1.000000
# portion = 0.005 #212:	num_val = 29	acc = 1.000000
# portion = 0.005 #213:	num_val = 29	acc = 0.965517
# portion = 0.005 #214:	num_val = 29	acc = 0.965517
# portion = 0.005 #215:	num_val = 29	acc = 1.000000
# portion = 0.005 #216:	num_val = 29	acc = 1.000000
# portion = 0.005 #217:	num_val = 29	acc = 1.000000
# portion = 0.005 #218:	num_val = 29	acc = 1.000000
# portion = 0.005 #219:	num_val = 29	acc = 0.965517
# portion = 0.005 #220:	num_val = 29	acc = 1.000000
# portion = 0.005 #221:	num_val = 29	acc = 1.000000
# portion = 0.005 #222:	num_val = 29	acc = 1.000000
# portion = 0.005 #223:	num_val = 29	acc = 1.000000
# portion = 0.005 #224:	num_val = 29	acc = 1.000000
# portion = 0.005 #225:	num_val = 29	acc = 1.000000
# portion = 0.005 #226:	num_val = 29	acc = 0.965517
# portion = 0.005 #227:	num_val = 29	acc = 1.000000
# portion = 0.005 #228:	num_val = 29	acc = 1.000000
# portion = 0.005 #229:	num_val = 29	acc = 1.000000
# portion = 0.005 #230:	num_val = 29	acc = 1.000000
# portion = 0.005 #231:	num_val = 29	acc = 1.000000
# portion = 0.005 #232:	num_val = 29	acc = 1.000000
# portion = 0.005 #233:	num_val = 29	acc = 1.000000
# portion = 0.005 #234:	num_val = 29	acc = 1.000000
# portion = 0.005 #235:	num_val = 29	acc = 1.000000
# portion = 0.005 #236:	num_val = 29	acc = 1.000000
# portion = 0.005 #237:	num_val = 29	acc = 1.000000
# portion = 0.005 #238:	num_val = 29	acc = 1.000000
# portion = 0.005 #239:	num_val = 29	acc = 1.000000
# portion = 0.005 #240:	num_val = 29	acc = 1.000000
# portion = 0.005 #241:	num_val = 29	acc = 0.965517
# portion = 0.005 #242:	num_val = 29	acc = 1.000000
# portion = 0.005 #243:	num_val = 29	acc = 0.965517
# portion = 0.005 #244:	num_val = 29	acc = 1.000000
# portion = 0.005 #245:	num_val = 29	acc = 0.965517
# portion = 0.005 #246:	num_val = 29	acc = 1.000000
# portion = 0.005 #247:	num_val = 29	acc = 1.000000
# portion = 0.005 #248:	num_val = 29	acc = 1.000000
# portion = 0.005 #249:	num_val = 29	acc = 1.000000
# portion = 0.005 #250:	num_val = 29	acc = 0.965517
# portion = 0.005 #251:	num_val = 29	acc = 1.000000
# portion = 0.005 #252:	num_val = 29	acc = 1.000000
# portion = 0.005 #253:	num_val = 29	acc = 1.000000
# portion = 0.005 #254:	num_val = 29	acc = 1.000000
# portion = 0.005 #255:	num_val = 29	acc = 1.000000
# portion = 0.005 #256:	num_val = 29	acc = 1.000000
# portion = 0.005 #257:	num_val = 29	acc = 0.965517
# portion = 0.005 #258:	num_val = 29	acc = 1.000000
# portion = 0.005 #259:	num_val = 29	acc = 1.000000
# portion = 0.005 #260:	num_val = 29	acc = 0.896552
# portion = 0.005 #261:	num_val = 29	acc = 1.000000
# portion = 0.005 #262:	num_val = 29	acc = 1.000000
# portion = 0.005 #263:	num_val = 29	acc = 0.931034
# portion = 0.005 #264:	num_val = 29	acc = 1.000000
# portion = 0.005 #265:	num_val = 29	acc = 0.965517
# portion = 0.005 #266:	num_val = 29	acc = 1.000000
# portion = 0.005 #267:	num_val = 29	acc = 0.965517
# portion = 0.005 #268:	num_val = 29	acc = 1.000000
# portion = 0.005 #269:	num_val = 29	acc = 0.965517
# portion = 0.005 #270:	num_val = 29	acc = 1.000000
# portion = 0.005 #271:	num_val = 29	acc = 0.965517
# portion = 0.005 #272:	num_val = 29	acc = 1.000000
# portion = 0.005 #273:	num_val = 29	acc = 1.000000
# portion = 0.005 #274:	num_val = 29	acc = 1.000000
# portion = 0.005 #275:	num_val = 29	acc = 1.000000
# portion = 0.005 #276:	num_val = 29	acc = 1.000000
# portion = 0.005 #277:	num_val = 29	acc = 1.000000
# portion = 0.005 #278:	num_val = 29	acc = 1.000000
# portion = 0.005 #279:	num_val = 29	acc = 1.000000
# portion = 0.005 #280:	num_val = 29	acc = 0.965517
# portion = 0.005 #281:	num_val = 29	acc = 1.000000
# portion = 0.005 #282:	num_val = 29	acc = 0.965517
# portion = 0.005 #283:	num_val = 29	acc = 1.000000
# portion = 0.005 #284:	num_val = 29	acc = 1.000000
# portion = 0.005 #285:	num_val = 29	acc = 1.000000
# portion = 0.005 #286:	num_val = 29	acc = 1.000000
# portion = 0.005 #287:	num_val = 29	acc = 1.000000
# portion = 0.005 #288:	num_val = 29	acc = 1.000000
# portion = 0.005 #289:	num_val = 29	acc = 1.000000
# portion = 0.005 #290:	num_val = 29	acc = 1.000000
# portion = 0.005 #291:	num_val = 29	acc = 0.965517
# portion = 0.005 #292:	num_val = 29	acc = 1.000000
# portion = 0.005 #293:	num_val = 29	acc = 0.896552
# portion = 0.005 #294:	num_val = 29	acc = 1.000000
# portion = 0.005 #295:	num_val = 29	acc = 0.965517
# portion = 0.005 #296:	num_val = 29	acc = 1.000000
# portion = 0.005 #297:	num_val = 29	acc = 1.000000
# portion = 0.005 #298:	num_val = 29	acc = 1.000000
# portion = 0.005 #299:	num_val = 29	acc = 1.000000
# portion = 0.005 #300:	num_val = 29	acc = 1.000000
# portion = 0.005 #301:	num_val = 29	acc = 1.000000
# portion = 0.005 #302:	num_val = 29	acc = 1.000000
# portion = 0.005 #303:	num_val = 29	acc = 0.931034
# portion = 0.005 #304:	num_val = 29	acc = 1.000000
# portion = 0.005 #305:	num_val = 29	acc = 0.965517
# portion = 0.005 #306:	num_val = 29	acc = 0.931034
# portion = 0.005 #307:	num_val = 29	acc = 1.000000
# portion = 0.005 #308:	num_val = 29	acc = 1.000000
# portion = 0.005 #309:	num_val = 29	acc = 0.965517
# portion = 0.005 #310:	num_val = 29	acc = 1.000000
# portion = 0.005 #311:	num_val = 29	acc = 1.000000
# portion = 0.005 #312:	num_val = 29	acc = 1.000000
# portion = 0.005 #313:	num_val = 29	acc = 1.000000
# portion = 0.005 #314:	num_val = 29	acc = 0.965517
# portion = 0.005 #315:	num_val = 29	acc = 0.931034
# portion = 0.005 #316:	num_val = 29	acc = 0.965517
# portion = 0.005 #317:	num_val = 29	acc = 1.000000
# portion = 0.005 #318:	num_val = 29	acc = 0.965517
# portion = 0.005 #319:	num_val = 29	acc = 1.000000
# portion = 0.005 #320:	num_val = 29	acc = 1.000000
# portion = 0.005 #321:	num_val = 29	acc = 0.862069
# portion = 0.005 #322:	num_val = 29	acc = 1.000000
# portion = 0.005 #323:	num_val = 29	acc = 1.000000
# portion = 0.005 #324:	num_val = 29	acc = 0.758621
# portion = 0.005 #325:	num_val = 29	acc = 1.000000
# portion = 0.005 #326:	num_val = 29	acc = 1.000000
# portion = 0.005 #327:	num_val = 29	acc = 1.000000
# portion = 0.005 #328:	num_val = 29	acc = 1.000000
# portion = 0.005 #329:	num_val = 29	acc = 0.965517
# portion = 0.005 #330:	num_val = 29	acc = 0.965517
# portion = 0.005 #331:	num_val = 29	acc = 1.000000
# portion = 0.005 #332:	num_val = 29	acc = 1.000000
# portion = 0.005 #333:	num_val = 29	acc = 1.000000
# portion = 0.005 #334:	num_val = 29	acc = 1.000000
# portion = 0.005 #335:	num_val = 29	acc = 1.000000
# portion = 0.005 #336:	num_val = 29	acc = 1.000000
# portion = 0.005 #337:	num_val = 29	acc = 0.965517
# portion = 0.005 #338:	num_val = 29	acc = 1.000000
# portion = 0.005 #339:	num_val = 29	acc = 1.000000
# portion = 0.005 #340:	num_val = 29	acc = 1.000000
# portion = 0.005 #341:	num_val = 29	acc = 1.000000
# portion = 0.005 #342:	num_val = 29	acc = 1.000000
# portion = 0.005 #343:	num_val = 29	acc = 1.000000
# portion = 0.005 #344:	num_val = 29	acc = 1.000000
# portion = 0.005 #345:	num_val = 29	acc = 1.000000
# portion = 0.005 #346:	num_val = 29	acc = 1.000000
# portion = 0.005 #347:	num_val = 29	acc = 0.965517
# portion = 0.005 #348:	num_val = 29	acc = 0.965517
# portion = 0.005 #349:	num_val = 29	acc = 1.000000
# portion = 0.005 #350:	num_val = 29	acc = 0.965517
# portion = 0.005 #351:	num_val = 29	acc = 1.000000
# portion = 0.005 #352:	num_val = 29	acc = 1.000000
# portion = 0.005 #353:	num_val = 29	acc = 1.000000
# portion = 0.005 #354:	num_val = 29	acc = 1.000000
# portion = 0.005 #355:	num_val = 29	acc = 1.000000
# portion = 0.005 #356:	num_val = 29	acc = 1.000000
# portion = 0.005 #357:	num_val = 29	acc = 1.000000
# portion = 0.005 #358:	num_val = 29	acc = 1.000000
# portion = 0.005 #359:	num_val = 29	acc = 1.000000
# portion = 0.005 #360:	num_val = 29	acc = 1.000000
# portion = 0.005 #361:	num_val = 29	acc = 1.000000
# portion = 0.005 #362:	num_val = 29	acc = 1.000000
# portion = 0.005 #363:	num_val = 29	acc = 1.000000
# portion = 0.005 #364:	num_val = 29	acc = 1.000000
# portion = 0.005 #365:	num_val = 29	acc = 0.965517
# portion = 0.005 #366:	num_val = 29	acc = 1.000000
# portion = 0.005 #367:	num_val = 29	acc = 1.000000
# portion = 0.005 #368:	num_val = 29	acc = 1.000000
# portion = 0.005 #369:	num_val = 29	acc = 1.000000
# portion = 0.005 #370:	num_val = 29	acc = 1.000000
# portion = 0.005 #371:	num_val = 29	acc = 1.000000
# portion = 0.005 #372:	num_val = 29	acc = 1.000000
# portion = 0.005 #373:	num_val = 29	acc = 1.000000
# portion = 0.005 #374:	num_val = 29	acc = 0.965517
# portion = 0.005 #375:	num_val = 29	acc = 1.000000
# portion = 0.005 #376:	num_val = 29	acc = 1.000000
# portion = 0.005 #377:	num_val = 29	acc = 1.000000
# portion = 0.005 #378:	num_val = 29	acc = 0.965517
# portion = 0.005 #379:	num_val = 29	acc = 1.000000
# portion = 0.005 #380:	num_val = 29	acc = 1.000000
# portion = 0.005 #381:	num_val = 29	acc = 1.000000
# portion = 0.005 #382:	num_val = 29	acc = 1.000000
# portion = 0.005 #383:	num_val = 29	acc = 1.000000
# portion = 0.005 #384:	num_val = 29	acc = 1.000000
# portion = 0.005 #385:	num_val = 29	acc = 1.000000
# portion = 0.005 #386:	num_val = 29	acc = 1.000000
# portion = 0.005 #387:	num_val = 29	acc = 1.000000
# portion = 0.005 #388:	num_val = 29	acc = 1.000000
# portion = 0.005 #389:	num_val = 29	acc = 1.000000
# portion = 0.005 #390:	num_val = 29	acc = 1.000000
# portion = 0.005 #391:	num_val = 29	acc = 1.000000
# portion = 0.005 #392:	num_val = 29	acc = 1.000000
# portion = 0.005 #393:	num_val = 29	acc = 1.000000
# portion = 0.005 #394:	num_val = 29	acc = 1.000000
# portion = 0.005 #395:	num_val = 29	acc = 1.000000
# portion = 0.005 #396:	num_val = 29	acc = 1.000000
# portion = 0.005 #397:	num_val = 29	acc = 1.000000
# portion = 0.005 #398:	num_val = 29	acc = 1.000000
# portion = 0.005 #399:	num_val = 29	acc = 0.965517
# portion = 0.005 #400:	num_val = 29	acc = 1.000000
# portion = 0.005 #401:	num_val = 29	acc = 1.000000
# portion = 0.005 #402:	num_val = 29	acc = 1.000000
# portion = 0.005 #403:	num_val = 29	acc = 1.000000
# portion = 0.005 #404:	num_val = 29	acc = 0.965517
# portion = 0.005 #405:	num_val = 29	acc = 1.000000
# portion = 0.005 #406:	num_val = 29	acc = 0.965517
# portion = 0.005 #407:	num_val = 29	acc = 0.965517
# portion = 0.005 #408:	num_val = 29	acc = 1.000000
# portion = 0.005 #409:	num_val = 29	acc = 1.000000
# portion = 0.005 #410:	num_val = 29	acc = 1.000000
# portion = 0.005 #411:	num_val = 29	acc = 1.000000
# portion = 0.005 #412:	num_val = 29	acc = 1.000000
# portion = 0.005 #413:	num_val = 29	acc = 1.000000
# portion = 0.005 #414:	num_val = 29	acc = 1.000000
# portion = 0.005 #415:	num_val = 29	acc = 0.965517
# portion = 0.005 #416:	num_val = 29	acc = 0.965517
# portion = 0.005 #417:	num_val = 29	acc = 1.000000
# portion = 0.005 #418:	num_val = 29	acc = 1.000000
# portion = 0.005 #419:	num_val = 29	acc = 1.000000
# portion = 0.005 #420:	num_val = 29	acc = 1.000000
# portion = 0.005 #421:	num_val = 29	acc = 1.000000
# portion = 0.005 #422:	num_val = 29	acc = 1.000000
# portion = 0.005 #423:	num_val = 29	acc = 1.000000
# portion = 0.005 #424:	num_val = 29	acc = 1.000000
# portion = 0.005 #425:	num_val = 29	acc = 1.000000
# portion = 0.005 #426:	num_val = 29	acc = 1.000000
# portion = 0.005 #427:	num_val = 29	acc = 1.000000
# portion = 0.005 #428:	num_val = 29	acc = 1.000000
# portion = 0.005 #429:	num_val = 29	acc = 0.482759
# portion = 0.005 #430:	num_val = 29	acc = 1.000000
# portion = 0.005 #431:	num_val = 29	acc = 1.000000
# portion = 0.005 #432:	num_val = 29	acc = 0.931034
# portion = 0.005 #433:	num_val = 29	acc = 1.000000
# portion = 0.005 #434:	num_val = 29	acc = 1.000000
# portion = 0.005 #435:	num_val = 29	acc = 0.965517
# portion = 0.005 #436:	num_val = 29	acc = 0.965517
# portion = 0.005 #437:	num_val = 29	acc = 0.965517
# portion = 0.005 #438:	num_val = 29	acc = 0.965517
# portion = 0.005 #439:	num_val = 29	acc = 1.000000
# portion = 0.005 #440:	num_val = 29	acc = 1.000000
# portion = 0.005 #441:	num_val = 29	acc = 1.000000
# portion = 0.005 #442:	num_val = 29	acc = 0.931034
# portion = 0.005 #443:	num_val = 29	acc = 1.000000
# portion = 0.005 #444:	num_val = 29	acc = 0.965517
# portion = 0.005 #445:	num_val = 29	acc = 1.000000
# portion = 0.005 #446:	num_val = 29	acc = 1.000000
# portion = 0.005 #447:	num_val = 29	acc = 1.000000
# portion = 0.005 #448:	num_val = 29	acc = 1.000000
# portion = 0.005 #449:	num_val = 29	acc = 0.965517
# portion = 0.005 #450:	num_val = 29	acc = 1.000000
# portion = 0.005 #451:	num_val = 29	acc = 1.000000
# portion = 0.005 #452:	num_val = 29	acc = 1.000000
# portion = 0.005 #453:	num_val = 29	acc = 1.000000
# portion = 0.005 #454:	num_val = 29	acc = 1.000000
# portion = 0.005 #455:	num_val = 29	acc = 0.965517
# portion = 0.005 #456:	num_val = 29	acc = 1.000000
# portion = 0.005 #457:	num_val = 29	acc = 0.965517
# portion = 0.005 #458:	num_val = 29	acc = 1.000000
# portion = 0.005 #459:	num_val = 29	acc = 1.000000
# portion = 0.005 #460:	num_val = 29	acc = 1.000000
# portion = 0.005 #461:	num_val = 29	acc = 1.000000
# portion = 0.005 #462:	num_val = 29	acc = 1.000000
# portion = 0.005 #463:	num_val = 29	acc = 1.000000
# portion = 0.005 #464:	num_val = 29	acc = 1.000000
# portion = 0.005 #465:	num_val = 29	acc = 1.000000
# portion = 0.005 #466:	num_val = 29	acc = 1.000000
# portion = 0.005 #467:	num_val = 29	acc = 0.965517
# portion = 0.005 #468:	num_val = 29	acc = 1.000000
# portion = 0.005 #469:	num_val = 29	acc = 0.896552
# portion = 0.005 #470:	num_val = 29	acc = 1.000000
# portion = 0.005 #471:	num_val = 29	acc = 1.000000
# portion = 0.005 #472:	num_val = 29	acc = 1.000000
# portion = 0.005 #473:	num_val = 29	acc = 0.413793
# portion = 0.005 #474:	num_val = 29	acc = 0.965517
# portion = 0.005 #475:	num_val = 29	acc = 1.000000
# portion = 0.005 #476:	num_val = 29	acc = 1.000000
# portion = 0.005 #477:	num_val = 29	acc = 1.000000
# portion = 0.005 #478:	num_val = 29	acc = 1.000000
# portion = 0.005 #479:	num_val = 29	acc = 1.000000
# portion = 0.005 #480:	num_val = 29	acc = 1.000000
# portion = 0.005 #481:	num_val = 29	acc = 0.965517
# portion = 0.005 #482:	num_val = 29	acc = 1.000000
# portion = 0.005 #483:	num_val = 29	acc = 1.000000
# portion = 0.005 #484:	num_val = 29	acc = 1.000000
# portion = 0.005 #485:	num_val = 29	acc = 1.000000
# portion = 0.005 #486:	num_val = 29	acc = 1.000000
# portion = 0.005 #487:	num_val = 29	acc = 0.551724
# portion = 0.005 #488:	num_val = 29	acc = 0.965517
# portion = 0.005 #489:	num_val = 29	acc = 1.000000
# portion = 0.005 #490:	num_val = 29	acc = 1.000000
# portion = 0.005 #491:	num_val = 29	acc = 1.000000
# portion = 0.005 #492:	num_val = 29	acc = 1.000000
# portion = 0.005 #493:	num_val = 29	acc = 1.000000
# portion = 0.005 #494:	num_val = 29	acc = 1.000000
# portion = 0.005 #495:	num_val = 29	acc = 0.965517
# portion = 0.005 #496:	num_val = 29	acc = 1.000000
# portion = 0.005 #497:	num_val = 29	acc = 1.000000
# portion = 0.005 #498:	num_val = 29	acc = 1.000000
# portion = 0.005 #499:	num_val = 29	acc = 0.931034
# portion = 0.005 #500:	num_val = 29	acc = 0.965517
# portion = 0.005 #501:	num_val = 29	acc = 1.000000
# portion = 0.005 #502:	num_val = 29	acc = 1.000000
# portion = 0.005 #503:	num_val = 29	acc = 1.000000
# portion = 0.005 #504:	num_val = 29	acc = 1.000000
# portion = 0.005 #505:	num_val = 29	acc = 1.000000
# portion = 0.005 #506:	num_val = 29	acc = 1.000000
# portion = 0.005 #507:	num_val = 29	acc = 0.724138
# portion = 0.005 #508:	num_val = 29	acc = 1.000000
# portion = 0.005 #509:	num_val = 29	acc = 1.000000
# portion = 0.005 #510:	num_val = 29	acc = 1.000000
# portion = 0.005 #511:	num_val = 29	acc = 0.965517
# portion = 0.005 #512:	num_val = 29	acc = 1.000000
# portion = 0.005 #513:	num_val = 29	acc = 1.000000
# portion = 0.005 #514:	num_val = 29	acc = 0.965517
# portion = 0.005 #515:	num_val = 29	acc = 1.000000
# portion = 0.005 #516:	num_val = 29	acc = 1.000000
# portion = 0.005 #517:	num_val = 29	acc = 0.965517
# portion = 0.005 #518:	num_val = 29	acc = 0.862069
# portion = 0.005 #519:	num_val = 29	acc = 1.000000
# portion = 0.005 #520:	num_val = 29	acc = 1.000000
# portion = 0.005 #521:	num_val = 29	acc = 1.000000
# portion = 0.005 #522:	num_val = 29	acc = 1.000000
# portion = 0.005 #523:	num_val = 29	acc = 1.000000
# portion = 0.005 #524:	num_val = 29	acc = 1.000000
# portion = 0.005 #525:	num_val = 29	acc = 1.000000
# portion = 0.005 #526:	num_val = 29	acc = 1.000000
# portion = 0.005 #527:	num_val = 29	acc = 1.000000
# portion = 0.005 #528:	num_val = 29	acc = 1.000000
# portion = 0.005 #529:	num_val = 29	acc = 1.000000
# portion = 0.005 #530:	num_val = 29	acc = 1.000000
# portion = 0.005 #531:	num_val = 29	acc = 1.000000
# portion = 0.005 #532:	num_val = 29	acc = 1.000000
# portion = 0.005 #533:	num_val = 29	acc = 1.000000
# portion = 0.005 #534:	num_val = 29	acc = 1.000000
# portion = 0.005 #535:	num_val = 29	acc = 1.000000
# portion = 0.005 #536:	num_val = 29	acc = 0.965517
# portion = 0.005 #537:	num_val = 29	acc = 0.965517
# portion = 0.005 #538:	num_val = 29	acc = 1.000000
# portion = 0.005 #539:	num_val = 29	acc = 0.965517
# portion = 0.005 #540:	num_val = 29	acc = 1.000000
# portion = 0.005 #541:	num_val = 29	acc = 0.965517
# portion = 0.005 #542:	num_val = 29	acc = 1.000000
# portion = 0.005 #543:	num_val = 29	acc = 1.000000
# portion = 0.005 #544:	num_val = 29	acc = 1.000000
# portion = 0.005 #545:	num_val = 29	acc = 1.000000
# portion = 0.005 #546:	num_val = 29	acc = 1.000000
# portion = 0.005 #547:	num_val = 29	acc = 1.000000
# portion = 0.005 #548:	num_val = 29	acc = 1.000000
# portion = 0.005 #549:	num_val = 29	acc = 1.000000
# portion = 0.005 #550:	num_val = 29	acc = 1.000000
# portion = 0.005 #551:	num_val = 29	acc = 1.000000
# portion = 0.005 #552:	num_val = 29	acc = 1.000000
# portion = 0.005 #553:	num_val = 29	acc = 1.000000
# portion = 0.005 #554:	num_val = 29	acc = 1.000000
# portion = 0.005 #555:	num_val = 29	acc = 0.965517
# portion = 0.005 #556:	num_val = 29	acc = 1.000000
# portion = 0.005 #557:	num_val = 29	acc = 1.000000
# portion = 0.005 #558:	num_val = 29	acc = 0.931034
# portion = 0.005 #559:	num_val = 29	acc = 1.000000
# portion = 0.005 #560:	num_val = 29	acc = 1.000000
# portion = 0.005 #561:	num_val = 29	acc = 1.000000
# portion = 0.005 #562:	num_val = 29	acc = 1.000000
# portion = 0.005 #563:	num_val = 29	acc = 1.000000
# portion = 0.005 #564:	num_val = 29	acc = 1.000000
# portion = 0.005 #565:	num_val = 29	acc = 1.000000
# portion = 0.005 #566:	num_val = 29	acc = 0.965517
# portion = 0.005 #567:	num_val = 29	acc = 1.000000
# portion = 0.005 #568:	num_val = 29	acc = 1.000000
# portion = 0.005 #569:	num_val = 29	acc = 1.000000
# portion = 0.005 #570:	num_val = 29	acc = 0.965517
# portion = 0.005 #571:	num_val = 29	acc = 1.000000
# portion = 0.005 #572:	num_val = 29	acc = 0.931034
# portion = 0.005 #573:	num_val = 29	acc = 0.965517
# portion = 0.005 #574:	num_val = 29	acc = 0.965517
# portion = 0.005 #575:	num_val = 29	acc = 0.965517
# portion = 0.005 #576:	num_val = 29	acc = 1.000000
# portion = 0.005 #577:	num_val = 29	acc = 1.000000
# portion = 0.005 #578:	num_val = 29	acc = 0.965517
# portion = 0.005 #579:	num_val = 29	acc = 1.000000
# portion = 0.005 #580:	num_val = 29	acc = 0.965517
# portion = 0.005 #581:	num_val = 29	acc = 1.000000
# portion = 0.005 #582:	num_val = 29	acc = 1.000000
# portion = 0.005 #583:	num_val = 29	acc = 1.000000
# portion = 0.005 #584:	num_val = 29	acc = 1.000000
# portion = 0.005 #585:	num_val = 29	acc = 1.000000
# portion = 0.005 #586:	num_val = 29	acc = 0.965517
# portion = 0.005 #587:	num_val = 29	acc = 1.000000
# portion = 0.005 #588:	num_val = 29	acc = 1.000000
# portion = 0.005 #589:	num_val = 29	acc = 1.000000
# portion = 0.005 #590:	num_val = 29	acc = 1.000000
# portion = 0.005 #591:	num_val = 29	acc = 0.896552
# portion = 0.005 #592:	num_val = 29	acc = 1.000000
# portion = 0.005 #593:	num_val = 29	acc = 0.965517
# portion = 0.005 #594:	num_val = 29	acc = 1.000000
# portion = 0.005 #595:	num_val = 29	acc = 1.000000
# portion = 0.005 #596:	num_val = 29	acc = 1.000000
# portion = 0.005 #597:	num_val = 29	acc = 1.000000
# portion = 0.005 #598:	num_val = 29	acc = 1.000000
# portion = 0.005 #599:	num_val = 29	acc = 1.000000
# portion = 0.005 #600:	num_val = 29	acc = 1.000000
# portion = 0.005 #601:	num_val = 29	acc = 1.000000
# portion = 0.005 #602:	num_val = 29	acc = 1.000000
# portion = 0.005 #603:	num_val = 29	acc = 1.000000
# portion = 0.005 #604:	num_val = 29	acc = 1.000000
# portion = 0.005 #605:	num_val = 29	acc = 1.000000
# portion = 0.005 #606:	num_val = 29	acc = 1.000000
# portion = 0.005 #607:	num_val = 29	acc = 1.000000
# portion = 0.005 #608:	num_val = 29	acc = 0.965517
# portion = 0.005 #609:	num_val = 29	acc = 1.000000
# portion = 0.005 #610:	num_val = 29	acc = 0.965517
# portion = 0.005 #611:	num_val = 29	acc = 1.000000
# portion = 0.005 #612:	num_val = 29	acc = 1.000000
# portion = 0.005 #613:	num_val = 29	acc = 1.000000
# portion = 0.005 #614:	num_val = 29	acc = 0.965517
# portion = 0.005 #615:	num_val = 29	acc = 1.000000
# portion = 0.005 #616:	num_val = 29	acc = 1.000000
# portion = 0.005 #617:	num_val = 29	acc = 1.000000
# portion = 0.005 #618:	num_val = 29	acc = 1.000000
# portion = 0.005 #619:	num_val = 29	acc = 1.000000
# portion = 0.005 #620:	num_val = 29	acc = 0.586207
# portion = 0.005 #621:	num_val = 29	acc = 0.931034
# portion = 0.005 #622:	num_val = 29	acc = 1.000000
# portion = 0.005 #623:	num_val = 29	acc = 1.000000
# portion = 0.005 #624:	num_val = 29	acc = 1.000000
# portion = 0.005 #625:	num_val = 29	acc = 0.862069
# portion = 0.005 #626:	num_val = 29	acc = 1.000000
# portion = 0.005 #627:	num_val = 29	acc = 1.000000
# portion = 0.005 #628:	num_val = 29	acc = 1.000000
# portion = 0.005 #629:	num_val = 29	acc = 0.965517
# portion = 0.005 #630:	num_val = 29	acc = 1.000000
# portion = 0.005 #631:	num_val = 29	acc = 1.000000
# portion = 0.005 #632:	num_val = 29	acc = 1.000000
# portion = 0.005 #633:	num_val = 29	acc = 1.000000
# portion = 0.005 #634:	num_val = 29	acc = 0.965517
# portion = 0.005 #635:	num_val = 29	acc = 1.000000
# portion = 0.005 #636:	num_val = 29	acc = 0.965517
# portion = 0.005 #637:	num_val = 29	acc = 1.000000
# portion = 0.005 #638:	num_val = 29	acc = 0.965517
# portion = 0.005 #639:	num_val = 29	acc = 1.000000
# portion = 0.005 #640:	num_val = 29	acc = 0.965517
# portion = 0.005 #641:	num_val = 29	acc = 1.000000
# portion = 0.005 #642:	num_val = 29	acc = 0.793103
# portion = 0.005 #643:	num_val = 29	acc = 1.000000
# portion = 0.005 #644:	num_val = 29	acc = 1.000000
# portion = 0.005 #645:	num_val = 29	acc = 1.000000
# portion = 0.005 #646:	num_val = 29	acc = 1.000000
# portion = 0.005 #647:	num_val = 29	acc = 1.000000
# portion = 0.005 #648:	num_val = 29	acc = 1.000000
# portion = 0.005 #649:	num_val = 29	acc = 0.517241
# portion = 0.005 #650:	num_val = 29	acc = 1.000000
# portion = 0.005 #651:	num_val = 29	acc = 1.000000
# portion = 0.005 #652:	num_val = 29	acc = 0.931034
# portion = 0.005 #653:	num_val = 29	acc = 1.000000
# portion = 0.005 #654:	num_val = 29	acc = 0.965517
# portion = 0.005 #655:	num_val = 29	acc = 1.000000
# portion = 0.005 #656:	num_val = 29	acc = 0.965517
# portion = 0.005 #657:	num_val = 29	acc = 1.000000
# portion = 0.005 #658:	num_val = 29	acc = 1.000000
# portion = 0.005 #659:	num_val = 29	acc = 1.000000
# portion = 0.005 #660:	num_val = 29	acc = 1.000000
# portion = 0.005 #661:	num_val = 29	acc = 1.000000
# portion = 0.005 #662:	num_val = 29	acc = 1.000000
# portion = 0.005 #663:	num_val = 29	acc = 1.000000
# portion = 0.005 #664:	num_val = 29	acc = 0.931034
# portion = 0.005 #665:	num_val = 29	acc = 1.000000
# portion = 0.005 #666:	num_val = 29	acc = 1.000000
# portion = 0.005 #667:	num_val = 29	acc = 0.965517
# portion = 0.005 #668:	num_val = 29	acc = 1.000000
# portion = 0.005 #669:	num_val = 29	acc = 1.000000
# portion = 0.005 #670:	num_val = 29	acc = 1.000000
# portion = 0.005 #671:	num_val = 29	acc = 1.000000
# portion = 0.005 #672:	num_val = 29	acc = 0.965517
# portion = 0.005 #673:	num_val = 29	acc = 1.000000
# portion = 0.005 #674:	num_val = 29	acc = 1.000000
# portion = 0.005 #675:	num_val = 29	acc = 1.000000
# portion = 0.005 #676:	num_val = 29	acc = 0.965517
# portion = 0.005 #677:	num_val = 29	acc = 1.000000
# portion = 0.005 #678:	num_val = 29	acc = 1.000000
# portion = 0.005 #679:	num_val = 29	acc = 1.000000
# portion = 0.005 #680:	num_val = 29	acc = 1.000000
# portion = 0.005 #681:	num_val = 29	acc = 1.000000
# portion = 0.005 #682:	num_val = 29	acc = 1.000000
# portion = 0.005 #683:	num_val = 29	acc = 1.000000
# portion = 0.005 #684:	num_val = 29	acc = 1.000000
# portion = 0.005 #685:	num_val = 29	acc = 0.965517
# portion = 0.005 #686:	num_val = 29	acc = 1.000000
# portion = 0.005 #687:	num_val = 29	acc = 1.000000
# portion = 0.005 #688:	num_val = 29	acc = 0.862069
# portion = 0.005 #689:	num_val = 29	acc = 1.000000
# portion = 0.005 #690:	num_val = 29	acc = 1.000000
# portion = 0.005 #691:	num_val = 29	acc = 1.000000
# portion = 0.005 #692:	num_val = 29	acc = 0.965517
# portion = 0.005 #693:	num_val = 29	acc = 1.000000
# portion = 0.005 #694:	num_val = 29	acc = 1.000000
# portion = 0.005 #695:	num_val = 29	acc = 1.000000
# portion = 0.005 #696:	num_val = 29	acc = 1.000000
# portion = 0.005 #697:	num_val = 29	acc = 1.000000
# portion = 0.005 #698:	num_val = 29	acc = 1.000000
# portion = 0.005 #699:	num_val = 29	acc = 1.000000
# portion = 0.005 #700:	num_val = 29	acc = 1.000000
# portion = 0.005 #701:	num_val = 29	acc = 0.931034
# portion = 0.005 #702:	num_val = 29	acc = 0.931034
# portion = 0.005 #703:	num_val = 29	acc = 0.965517
# portion = 0.005 #704:	num_val = 29	acc = 1.000000
# portion = 0.005 #705:	num_val = 29	acc = 0.931034
# portion = 0.005 #706:	num_val = 29	acc = 1.000000
# portion = 0.005 #707:	num_val = 29	acc = 0.965517
# portion = 0.005 #708:	num_val = 29	acc = 1.000000
# portion = 0.005 #709:	num_val = 29	acc = 1.000000
# portion = 0.005 #710:	num_val = 29	acc = 0.965517
# portion = 0.005 #711:	num_val = 29	acc = 1.000000
# portion = 0.005 #712:	num_val = 29	acc = 1.000000
# portion = 0.005 #713:	num_val = 29	acc = 1.000000
# portion = 0.005 #714:	num_val = 29	acc = 1.000000
# portion = 0.005 #715:	num_val = 29	acc = 1.000000
# portion = 0.005 #716:	num_val = 29	acc = 1.000000
# portion = 0.005 #717:	num_val = 29	acc = 1.000000
# portion = 0.005 #718:	num_val = 29	acc = 0.965517
# portion = 0.005 #719:	num_val = 29	acc = 1.000000
# portion = 0.005 #720:	num_val = 29	acc = 1.000000
# portion = 0.005 #721:	num_val = 29	acc = 1.000000
# portion = 0.005 #722:	num_val = 29	acc = 1.000000
# portion = 0.005 #723:	num_val = 29	acc = 1.000000
# portion = 0.005 #724:	num_val = 29	acc = 1.000000
# portion = 0.005 #725:	num_val = 29	acc = 0.965517
# portion = 0.005 #726:	num_val = 29	acc = 1.000000
# portion = 0.005 #727:	num_val = 29	acc = 0.965517
# portion = 0.005 #728:	num_val = 29	acc = 1.000000
# portion = 0.005 #729:	num_val = 29	acc = 1.000000
# portion = 0.005 #730:	num_val = 29	acc = 0.965517
# portion = 0.005 #731:	num_val = 29	acc = 0.965517
# portion = 0.005 #732:	num_val = 29	acc = 1.000000
# portion = 0.005 #733:	num_val = 29	acc = 1.000000
# portion = 0.005 #734:	num_val = 29	acc = 1.000000
# portion = 0.005 #735:	num_val = 29	acc = 1.000000
# portion = 0.005 #736:	num_val = 29	acc = 1.000000
# portion = 0.005 #737:	num_val = 29	acc = 1.000000
# portion = 0.005 #738:	num_val = 29	acc = 1.000000
# portion = 0.005 #739:	num_val = 29	acc = 1.000000
# portion = 0.005 #740:	num_val = 29	acc = 1.000000
# portion = 0.005 #741:	num_val = 29	acc = 1.000000
# portion = 0.005 #742:	num_val = 29	acc = 1.000000
# portion = 0.005 #743:	num_val = 29	acc = 0.965517
# portion = 0.005 #744:	num_val = 29	acc = 1.000000
# portion = 0.005 #745:	num_val = 29	acc = 0.931034
# portion = 0.005 #746:	num_val = 29	acc = 0.896552
# portion = 0.005 #747:	num_val = 29	acc = 1.000000
# portion = 0.005 #748:	num_val = 29	acc = 0.931034
# portion = 0.005 #749:	num_val = 29	acc = 1.000000
# portion = 0.005 #750:	num_val = 29	acc = 1.000000
# portion = 0.005 #751:	num_val = 29	acc = 1.000000
# portion = 0.005 #752:	num_val = 29	acc = 1.000000
# portion = 0.005 #753:	num_val = 29	acc = 1.000000
# portion = 0.005 #754:	num_val = 29	acc = 0.965517
# portion = 0.005 #755:	num_val = 29	acc = 0.931034
# portion = 0.005 #756:	num_val = 29	acc = 1.000000
# portion = 0.005 #757:	num_val = 29	acc = 1.000000
# portion = 0.005 #758:	num_val = 29	acc = 1.000000
# portion = 0.005 #759:	num_val = 29	acc = 1.000000
# portion = 0.005 #760:	num_val = 29	acc = 1.000000
# portion = 0.005 #761:	num_val = 29	acc = 0.965517
# portion = 0.005 #762:	num_val = 29	acc = 1.000000
# portion = 0.005 #763:	num_val = 29	acc = 1.000000
# portion = 0.005 #764:	num_val = 29	acc = 1.000000
# portion = 0.005 #765:	num_val = 29	acc = 1.000000
# portion = 0.005 #766:	num_val = 29	acc = 0.931034
# portion = 0.005 #767:	num_val = 29	acc = 1.000000
# portion = 0.005 #768:	num_val = 29	acc = 1.000000
# portion = 0.005 #769:	num_val = 29	acc = 1.000000
# portion = 0.005 #770:	num_val = 29	acc = 1.000000
# portion = 0.005 #771:	num_val = 29	acc = 1.000000
# portion = 0.005 #772:	num_val = 29	acc = 1.000000
# portion = 0.005 #773:	num_val = 29	acc = 1.000000
# portion = 0.005 #774:	num_val = 29	acc = 0.965517
# portion = 0.005 #775:	num_val = 29	acc = 1.000000
# portion = 0.005 #776:	num_val = 29	acc = 0.620690
# portion = 0.005 #777:	num_val = 29	acc = 1.000000
# portion = 0.005 #778:	num_val = 29	acc = 1.000000
# portion = 0.005 #779:	num_val = 29	acc = 0.931034
# portion = 0.005 #780:	num_val = 29	acc = 1.000000
# portion = 0.005 #781:	num_val = 29	acc = 1.000000
# portion = 0.005 #782:	num_val = 29	acc = 1.000000
# portion = 0.005 #783:	num_val = 29	acc = 1.000000
# portion = 0.005 #784:	num_val = 29	acc = 1.000000
# portion = 0.005 #785:	num_val = 29	acc = 1.000000
# portion = 0.005 #786:	num_val = 29	acc = 1.000000
# portion = 0.005 #787:	num_val = 29	acc = 1.000000
# portion = 0.005 #788:	num_val = 29	acc = 1.000000
# portion = 0.005 #789:	num_val = 29	acc = 1.000000
# portion = 0.005 #790:	num_val = 29	acc = 1.000000
# portion = 0.005 #791:	num_val = 29	acc = 1.000000
# portion = 0.005 #792:	num_val = 29	acc = 0.965517
# portion = 0.005 #793:	num_val = 29	acc = 1.000000
# portion = 0.005 #794:	num_val = 29	acc = 1.000000
# portion = 0.005 #795:	num_val = 29	acc = 1.000000
# portion = 0.005 #796:	num_val = 29	acc = 1.000000
# portion = 0.005 #797:	num_val = 29	acc = 1.000000
# portion = 0.005 #798:	num_val = 29	acc = 1.000000
# portion = 0.005 #799:	num_val = 29	acc = 1.000000
# portion = 0.005 #800:	num_val = 29	acc = 0.965517
# portion = 0.005 #801:	num_val = 29	acc = 1.000000
# portion = 0.005 #802:	num_val = 29	acc = 1.000000
# portion = 0.005 #803:	num_val = 29	acc = 1.000000
# portion = 0.005 #804:	num_val = 29	acc = 1.000000
# portion = 0.005 #805:	num_val = 29	acc = 1.000000
# portion = 0.005 #806:	num_val = 29	acc = 0.965517
# portion = 0.005 #807:	num_val = 29	acc = 1.000000
# portion = 0.005 #808:	num_val = 29	acc = 1.000000
# portion = 0.005 #809:	num_val = 29	acc = 1.000000
# portion = 0.005 #810:	num_val = 29	acc = 0.965517
# portion = 0.005 #811:	num_val = 29	acc = 0.965517
# portion = 0.005 #812:	num_val = 29	acc = 1.000000
# portion = 0.005 #813:	num_val = 29	acc = 1.000000
# portion = 0.005 #814:	num_val = 29	acc = 1.000000
# portion = 0.005 #815:	num_val = 29	acc = 1.000000
# portion = 0.005 #816:	num_val = 29	acc = 1.000000
# portion = 0.005 #817:	num_val = 29	acc = 1.000000
# portion = 0.005 #818:	num_val = 29	acc = 0.965517
# portion = 0.005 #819:	num_val = 29	acc = 1.000000
# portion = 0.005 #820:	num_val = 29	acc = 0.586207
# portion = 0.005 #821:	num_val = 29	acc = 1.000000
# portion = 0.005 #822:	num_val = 29	acc = 1.000000
# portion = 0.005 #823:	num_val = 29	acc = 1.000000
# portion = 0.005 #824:	num_val = 29	acc = 0.931034
# portion = 0.005 #825:	num_val = 29	acc = 1.000000
# portion = 0.005 #826:	num_val = 29	acc = 1.000000
# portion = 0.005 #827:	num_val = 29	acc = 1.000000
# portion = 0.005 #828:	num_val = 29	acc = 1.000000
# portion = 0.005 #829:	num_val = 29	acc = 1.000000
# portion = 0.005 #830:	num_val = 29	acc = 1.000000
# portion = 0.005 #831:	num_val = 29	acc = 0.965517
# portion = 0.005 #832:	num_val = 29	acc = 1.000000
# portion = 0.005 #833:	num_val = 29	acc = 1.000000
# portion = 0.005 #834:	num_val = 29	acc = 1.000000
# portion = 0.005 #835:	num_val = 29	acc = 1.000000
# portion = 0.005 #836:	num_val = 29	acc = 1.000000
# portion = 0.005 #837:	num_val = 29	acc = 0.482759
# portion = 0.005 #838:	num_val = 29	acc = 1.000000
# portion = 0.005 #839:	num_val = 29	acc = 1.000000
# portion = 0.005 #840:	num_val = 29	acc = 1.000000
# portion = 0.005 #841:	num_val = 29	acc = 1.000000
# portion = 0.005 #842:	num_val = 29	acc = 1.000000
# portion = 0.005 #843:	num_val = 29	acc = 1.000000
# portion = 0.005 #844:	num_val = 29	acc = 1.000000
# portion = 0.005 #845:	num_val = 29	acc = 1.000000
# portion = 0.005 #846:	num_val = 29	acc = 0.965517
# portion = 0.005 #847:	num_val = 29	acc = 1.000000
# portion = 0.005 #848:	num_val = 29	acc = 1.000000
# portion = 0.005 #849:	num_val = 29	acc = 1.000000
# portion = 0.005 #850:	num_val = 29	acc = 1.000000
# portion = 0.005 #851:	num_val = 29	acc = 1.000000
# portion = 0.005 #852:	num_val = 29	acc = 1.000000
# portion = 0.005 #853:	num_val = 29	acc = 0.965517
# portion = 0.005 #854:	num_val = 29	acc = 1.000000
# portion = 0.005 #855:	num_val = 29	acc = 1.000000
# portion = 0.005 #856:	num_val = 29	acc = 1.000000
# portion = 0.005 #857:	num_val = 29	acc = 1.000000
# portion = 0.005 #858:	num_val = 29	acc = 1.000000
# portion = 0.005 #859:	num_val = 29	acc = 0.931034
# portion = 0.005 #860:	num_val = 29	acc = 0.965517
# portion = 0.005 #861:	num_val = 29	acc = 1.000000
# portion = 0.005 #862:	num_val = 29	acc = 1.000000
# portion = 0.005 #863:	num_val = 29	acc = 1.000000
# portion = 0.005 #864:	num_val = 29	acc = 0.931034
# portion = 0.005 #865:	num_val = 29	acc = 1.000000
# portion = 0.005 #866:	num_val = 29	acc = 1.000000
# portion = 0.005 #867:	num_val = 29	acc = 1.000000
# portion = 0.005 #868:	num_val = 29	acc = 1.000000
# portion = 0.005 #869:	num_val = 29	acc = 1.000000
# portion = 0.005 #870:	num_val = 29	acc = 0.965517
# portion = 0.005 #871:	num_val = 29	acc = 1.000000
# portion = 0.005 #872:	num_val = 29	acc = 1.000000
# portion = 0.005 #873:	num_val = 29	acc = 1.000000
# portion = 0.005 #874:	num_val = 29	acc = 1.000000
# portion = 0.005 #875:	num_val = 29	acc = 1.000000
# portion = 0.005 #876:	num_val = 29	acc = 1.000000
# portion = 0.005 #877:	num_val = 29	acc = 1.000000
# portion = 0.005 #878:	num_val = 29	acc = 1.000000
# portion = 0.005 #879:	num_val = 29	acc = 1.000000
# portion = 0.005 #880:	num_val = 29	acc = 1.000000
# portion = 0.005 #881:	num_val = 29	acc = 0.965517
# portion = 0.005 #882:	num_val = 29	acc = 1.000000
# portion = 0.005 #883:	num_val = 29	acc = 0.965517
# portion = 0.005 #884:	num_val = 29	acc = 1.000000
# portion = 0.005 #885:	num_val = 29	acc = 1.000000
# portion = 0.005 #886:	num_val = 29	acc = 1.000000
# portion = 0.005 #887:	num_val = 29	acc = 0.965517
# portion = 0.005 #888:	num_val = 29	acc = 1.000000
# portion = 0.005 #889:	num_val = 29	acc = 1.000000
# portion = 0.005 #890:	num_val = 29	acc = 1.000000
# portion = 0.005 #891:	num_val = 29	acc = 1.000000
# portion = 0.005 #892:	num_val = 29	acc = 1.000000
# portion = 0.005 #893:	num_val = 29	acc = 1.000000
# portion = 0.005 #894:	num_val = 29	acc = 1.000000
# portion = 0.005 #895:	num_val = 29	acc = 1.000000
# portion = 0.005 #896:	num_val = 29	acc = 1.000000
# portion = 0.005 #897:	num_val = 29	acc = 0.931034
# portion = 0.005 #898:	num_val = 29	acc = 1.000000
# portion = 0.005 #899:	num_val = 29	acc = 1.000000
# portion = 0.005 #900:	num_val = 29	acc = 1.000000
# portion = 0.005 #901:	num_val = 29	acc = 1.000000
# portion = 0.005 #902:	num_val = 29	acc = 1.000000
# portion = 0.005 #903:	num_val = 29	acc = 1.000000
# portion = 0.005 #904:	num_val = 29	acc = 0.965517
# portion = 0.005 #905:	num_val = 29	acc = 1.000000
# portion = 0.005 #906:	num_val = 29	acc = 1.000000
# portion = 0.005 #907:	num_val = 29	acc = 1.000000
# portion = 0.005 #908:	num_val = 29	acc = 1.000000
# portion = 0.005 #909:	num_val = 29	acc = 1.000000
# portion = 0.005 #910:	num_val = 29	acc = 1.000000
# portion = 0.005 #911:	num_val = 29	acc = 1.000000
# portion = 0.005 #912:	num_val = 29	acc = 1.000000
# portion = 0.005 #913:	num_val = 29	acc = 1.000000
# portion = 0.005 #914:	num_val = 29	acc = 1.000000
# portion = 0.005 #915:	num_val = 29	acc = 1.000000
# portion = 0.005 #916:	num_val = 29	acc = 1.000000
# portion = 0.005 #917:	num_val = 29	acc = 1.000000
# portion = 0.005 #918:	num_val = 29	acc = 1.000000
# portion = 0.005 #919:	num_val = 29	acc = 1.000000
# portion = 0.005 #920:	num_val = 29	acc = 1.000000
# portion = 0.005 #921:	num_val = 29	acc = 1.000000
# portion = 0.005 #922:	num_val = 29	acc = 0.931034
# portion = 0.005 #923:	num_val = 29	acc = 1.000000
# portion = 0.005 #924:	num_val = 29	acc = 1.000000
# portion = 0.005 #925:	num_val = 29	acc = 1.000000
# portion = 0.005 #926:	num_val = 29	acc = 1.000000
# portion = 0.005 #927:	num_val = 29	acc = 1.000000
# portion = 0.005 #928:	num_val = 29	acc = 1.000000
# portion = 0.005 #929:	num_val = 29	acc = 1.000000
# portion = 0.005 #930:	num_val = 29	acc = 0.965517
# portion = 0.005 #931:	num_val = 29	acc = 0.965517
# portion = 0.005 #932:	num_val = 29	acc = 1.000000
# portion = 0.005 #933:	num_val = 29	acc = 1.000000
# portion = 0.005 #934:	num_val = 29	acc = 1.000000
# portion = 0.005 #935:	num_val = 29	acc = 0.965517
# portion = 0.005 #936:	num_val = 29	acc = 0.965517
# portion = 0.005 #937:	num_val = 29	acc = 1.000000
# portion = 0.005 #938:	num_val = 29	acc = 1.000000
# portion = 0.005 #939:	num_val = 29	acc = 1.000000
# portion = 0.005 #940:	num_val = 29	acc = 1.000000
# portion = 0.005 #941:	num_val = 29	acc = 1.000000
# portion = 0.005 #942:	num_val = 29	acc = 1.000000
# portion = 0.005 #943:	num_val = 29	acc = 1.000000
# portion = 0.005 #944:	num_val = 29	acc = 1.000000
# portion = 0.005 #945:	num_val = 29	acc = 1.000000
# portion = 0.005 #946:	num_val = 29	acc = 0.793103
# portion = 0.005 #947:	num_val = 29	acc = 0.965517
# portion = 0.005 #948:	num_val = 29	acc = 1.000000
# portion = 0.005 #949:	num_val = 29	acc = 0.965517
# portion = 0.005 #950:	num_val = 29	acc = 1.000000
# portion = 0.005 #951:	num_val = 29	acc = 1.000000
# portion = 0.005 #952:	num_val = 29	acc = 1.000000
# portion = 0.005 #953:	num_val = 29	acc = 1.000000
# portion = 0.005 #954:	num_val = 29	acc = 1.000000
# portion = 0.005 #955:	num_val = 29	acc = 1.000000
# portion = 0.005 #956:	num_val = 29	acc = 0.965517
# portion = 0.005 #957:	num_val = 29	acc = 1.000000
# portion = 0.005 #958:	num_val = 29	acc = 1.000000
# portion = 0.005 #959:	num_val = 29	acc = 1.000000
# portion = 0.005 #960:	num_val = 29	acc = 0.965517
# portion = 0.005 #961:	num_val = 29	acc = 0.965517
# ...
# portion = 0.02 #9688:	num_val = 118	acc = 0.991525
# portion = 0.02 #9689:	num_val = 118	acc = 1.000000
# portion = 0.02 #9690:	num_val = 118	acc = 0.991525
# portion = 0.02 #9691:	num_val = 118	acc = 0.991525
# portion = 0.02 #9692:	num_val = 118	acc = 0.991525
# portion = 0.02 #9693:	num_val = 118	acc = 0.966102
# portion = 0.02 #9694:	num_val = 118	acc = 1.000000
# portion = 0.02 #9695:	num_val = 118	acc = 0.991525
# portion = 0.02 #9696:	num_val = 118	acc = 0.991525
# portion = 0.02 #9697:	num_val = 118	acc = 1.000000
# portion = 0.02 #9698:	num_val = 118	acc = 0.991525
# portion = 0.02 #9699:	num_val = 118	acc = 1.000000
# portion = 0.02 #9700:	num_val = 118	acc = 1.000000
# portion = 0.02 #9701:	num_val = 118	acc = 0.991525
# portion = 0.02 #9702:	num_val = 118	acc = 0.991525
# portion = 0.02 #9703:	num_val = 118	acc = 1.000000
# portion = 0.02 #9704:	num_val = 118	acc = 1.000000
# portion = 0.02 #9705:	num_val = 118	acc = 1.000000
# portion = 0.02 #9706:	num_val = 118	acc = 0.991525
# portion = 0.02 #9707:	num_val = 118	acc = 0.991525
# portion = 0.02 #9708:	num_val = 118	acc = 0.991525
# portion = 0.02 #9709:	num_val = 118	acc = 1.000000
# portion = 0.02 #9710:	num_val = 118	acc = 1.000000
# portion = 0.02 #9711:	num_val = 118	acc = 0.974576
# portion = 0.02 #9712:	num_val = 118	acc = 0.983051
# portion = 0.02 #9713:	num_val = 118	acc = 1.000000
# portion = 0.02 #9714:	num_val = 118	acc = 0.991525
# portion = 0.02 #9715:	num_val = 118	acc = 1.000000
# portion = 0.02 #9716:	num_val = 118	acc = 1.000000
# portion = 0.02 #9717:	num_val = 118	acc = 1.000000
# portion = 0.02 #9718:	num_val = 118	acc = 1.000000
# portion = 0.02 #9719:	num_val = 118	acc = 1.000000
# portion = 0.02 #9720:	num_val = 118	acc = 1.000000
# portion = 0.02 #9721:	num_val = 118	acc = 0.991525
# portion = 0.02 #9722:	num_val = 118	acc = 1.000000
# portion = 0.02 #9723:	num_val = 118	acc = 0.991525
# portion = 0.02 #9724:	num_val = 118	acc = 0.991525
# portion = 0.02 #9725:	num_val = 118	acc = 1.000000
# portion = 0.02 #9726:	num_val = 118	acc = 1.000000
# portion = 0.02 #9727:	num_val = 118	acc = 1.000000
# portion = 0.02 #9728:	num_val = 118	acc = 1.000000
# portion = 0.02 #9729:	num_val = 118	acc = 1.000000
# portion = 0.02 #9730:	num_val = 118	acc = 0.991525
# portion = 0.02 #9731:	num_val = 118	acc = 1.000000
# portion = 0.02 #9732:	num_val = 118	acc = 0.991525
# portion = 0.02 #9733:	num_val = 118	acc = 1.000000
# portion = 0.02 #9734:	num_val = 118	acc = 0.991525
# portion = 0.02 #9735:	num_val = 118	acc = 0.991525
# portion = 0.02 #9736:	num_val = 118	acc = 1.000000
# portion = 0.02 #9737:	num_val = 118	acc = 0.991525
# portion = 0.02 #9738:	num_val = 118	acc = 0.991525
# portion = 0.02 #9739:	num_val = 118	acc = 0.991525
# portion = 0.02 #9740:	num_val = 118	acc = 0.991525
# portion = 0.02 #9741:	num_val = 118	acc = 1.000000
# portion = 0.02 #9742:	num_val = 118	acc = 0.991525
# portion = 0.02 #9743:	num_val = 118	acc = 0.991525
# portion = 0.02 #9744:	num_val = 118	acc = 0.991525
# portion = 0.02 #9745:	num_val = 118	acc = 1.000000
# portion = 0.02 #9746:	num_val = 118	acc = 0.991525
# portion = 0.02 #9747:	num_val = 118	acc = 1.000000
# portion = 0.02 #9748:	num_val = 118	acc = 1.000000
# portion = 0.02 #9749:	num_val = 118	acc = 1.000000
# portion = 0.02 #9750:	num_val = 118	acc = 0.991525
# portion = 0.02 #9751:	num_val = 118	acc = 1.000000
# portion = 0.02 #9752:	num_val = 118	acc = 0.991525
# portion = 0.02 #9753:	num_val = 118	acc = 0.957627
# portion = 0.02 #9754:	num_val = 118	acc = 1.000000
# portion = 0.02 #9755:	num_val = 118	acc = 0.983051
# portion = 0.02 #9756:	num_val = 118	acc = 1.000000
# portion = 0.02 #9757:	num_val = 118	acc = 1.000000
# portion = 0.02 #9758:	num_val = 118	acc = 0.991525
# portion = 0.02 #9759:	num_val = 118	acc = 0.983051
# portion = 0.02 #9760:	num_val = 118	acc = 0.966102
# portion = 0.02 #9761:	num_val = 118	acc = 1.000000
# portion = 0.02 #9762:	num_val = 118	acc = 0.966102
# portion = 0.02 #9763:	num_val = 118	acc = 1.000000
# portion = 0.02 #9764:	num_val = 118	acc = 0.983051
# portion = 0.02 #9765:	num_val = 118	acc = 1.000000
# portion = 0.02 #9766:	num_val = 118	acc = 1.000000
# portion = 0.02 #9767:	num_val = 118	acc = 1.000000
# portion = 0.02 #9768:	num_val = 118	acc = 0.991525
# portion = 0.02 #9769:	num_val = 118	acc = 1.000000
# portion = 0.02 #9770:	num_val = 118	acc = 0.983051
# portion = 0.02 #9771:	num_val = 118	acc = 1.000000
# portion = 0.02 #9772:	num_val = 118	acc = 1.000000
# portion = 0.02 #9773:	num_val = 118	acc = 0.991525
# portion = 0.02 #9774:	num_val = 118	acc = 1.000000
# portion = 0.02 #9775:	num_val = 118	acc = 1.000000
# portion = 0.02 #9776:	num_val = 118	acc = 1.000000
# portion = 0.02 #9777:	num_val = 118	acc = 0.991525
# portion = 0.02 #9778:	num_val = 118	acc = 0.983051
# portion = 0.02 #9779:	num_val = 118	acc = 0.991525
# portion = 0.02 #9780:	num_val = 118	acc = 1.000000
# portion = 0.02 #9781:	num_val = 118	acc = 1.000000
# portion = 0.02 #9782:	num_val = 118	acc = 1.000000
# portion = 0.02 #9783:	num_val = 118	acc = 1.000000
# portion = 0.02 #9784:	num_val = 118	acc = 1.000000
# portion = 0.02 #9785:	num_val = 118	acc = 0.991525
# portion = 0.02 #9786:	num_val = 118	acc = 0.991525
# portion = 0.02 #9787:	num_val = 118	acc = 0.974576
# portion = 0.02 #9788:	num_val = 118	acc = 0.991525
# portion = 0.02 #9789:	num_val = 118	acc = 1.000000
# portion = 0.02 #9790:	num_val = 118	acc = 1.000000
# portion = 0.02 #9791:	num_val = 118	acc = 1.000000
# portion = 0.02 #9792:	num_val = 118	acc = 1.000000
# portion = 0.02 #9793:	num_val = 118	acc = 0.991525
# portion = 0.02 #9794:	num_val = 118	acc = 0.991525
# portion = 0.02 #9795:	num_val = 118	acc = 1.000000
# portion = 0.02 #9796:	num_val = 118	acc = 0.991525
# portion = 0.02 #9797:	num_val = 118	acc = 0.983051
# portion = 0.02 #9798:	num_val = 118	acc = 0.991525
# portion = 0.02 #9799:	num_val = 118	acc = 0.991525
# portion = 0.02 #9800:	num_val = 118	acc = 1.000000
# portion = 0.02 #9801:	num_val = 118	acc = 0.991525
# portion = 0.02 #9802:	num_val = 118	acc = 0.991525
# portion = 0.02 #9803:	num_val = 118	acc = 1.000000
# portion = 0.02 #9804:	num_val = 118	acc = 0.991525
# portion = 0.02 #9805:	num_val = 118	acc = 0.983051
# portion = 0.02 #9806:	num_val = 118	acc = 1.000000
# portion = 0.02 #9807:	num_val = 118	acc = 0.991525
# portion = 0.02 #9808:	num_val = 118	acc = 0.983051
# portion = 0.02 #9809:	num_val = 118	acc = 1.000000
# portion = 0.02 #9810:	num_val = 118	acc = 1.000000
# portion = 0.02 #9811:	num_val = 118	acc = 1.000000
# portion = 0.02 #9812:	num_val = 118	acc = 1.000000
# portion = 0.02 #9813:	num_val = 118	acc = 1.000000
# portion = 0.02 #9814:	num_val = 118	acc = 1.000000
# portion = 0.02 #9815:	num_val = 118	acc = 0.991525
# portion = 0.02 #9816:	num_val = 118	acc = 1.000000
# portion = 0.02 #9817:	num_val = 118	acc = 0.991525
# portion = 0.02 #9818:	num_val = 118	acc = 0.983051
# portion = 0.02 #9819:	num_val = 118	acc = 0.991525
# portion = 0.02 #9820:	num_val = 118	acc = 0.991525
# portion = 0.02 #9821:	num_val = 118	acc = 0.991525
# portion = 0.02 #9822:	num_val = 118	acc = 0.991525
# portion = 0.02 #9823:	num_val = 118	acc = 0.983051
# portion = 0.02 #9824:	num_val = 118	acc = 0.550847
# portion = 0.02 #9825:	num_val = 118	acc = 1.000000
# portion = 0.02 #9826:	num_val = 118	acc = 0.991525
# portion = 0.02 #9827:	num_val = 118	acc = 1.000000
# portion = 0.02 #9828:	num_val = 118	acc = 0.991525
# portion = 0.02 #9829:	num_val = 118	acc = 1.000000
# portion = 0.02 #9830:	num_val = 118	acc = 0.991525
# portion = 0.02 #9831:	num_val = 118	acc = 0.991525
# portion = 0.02 #9832:	num_val = 118	acc = 1.000000
# portion = 0.02 #9833:	num_val = 118	acc = 0.974576
# portion = 0.02 #9834:	num_val = 118	acc = 0.991525
# portion = 0.02 #9835:	num_val = 118	acc = 0.991525
# portion = 0.02 #9836:	num_val = 118	acc = 0.991525
# portion = 0.02 #9837:	num_val = 118	acc = 1.000000
# portion = 0.02 #9838:	num_val = 118	acc = 1.000000
# portion = 0.02 #9839:	num_val = 118	acc = 0.991525
# portion = 0.02 #9840:	num_val = 118	acc = 0.991525
# portion = 0.02 #9841:	num_val = 118	acc = 1.000000
# portion = 0.02 #9842:	num_val = 118	acc = 1.000000
# portion = 0.02 #9843:	num_val = 118	acc = 1.000000
# portion = 0.02 #9844:	num_val = 118	acc = 0.991525
# portion = 0.02 #9845:	num_val = 118	acc = 0.991525
# portion = 0.02 #9846:	num_val = 118	acc = 1.000000
# portion = 0.02 #9847:	num_val = 118	acc = 0.974576
# portion = 0.02 #9848:	num_val = 118	acc = 1.000000
# portion = 0.02 #9849:	num_val = 118	acc = 1.000000
# portion = 0.02 #9850:	num_val = 118	acc = 1.000000
# portion = 0.02 #9851:	num_val = 118	acc = 1.000000
# portion = 0.02 #9852:	num_val = 118	acc = 1.000000
# portion = 0.02 #9853:	num_val = 118	acc = 1.000000
# portion = 0.02 #9854:	num_val = 118	acc = 1.000000
# portion = 0.02 #9855:	num_val = 118	acc = 1.000000
# portion = 0.02 #9856:	num_val = 118	acc = 0.983051
# portion = 0.02 #9857:	num_val = 118	acc = 1.000000
# portion = 0.02 #9858:	num_val = 118	acc = 1.000000
# portion = 0.02 #9859:	num_val = 118	acc = 0.991525
# portion = 0.02 #9860:	num_val = 118	acc = 0.991525
# portion = 0.02 #9861:	num_val = 118	acc = 0.991525
# portion = 0.02 #9862:	num_val = 118	acc = 1.000000
# portion = 0.02 #9863:	num_val = 118	acc = 0.991525
# portion = 0.02 #9864:	num_val = 118	acc = 1.000000
# portion = 0.02 #9865:	num_val = 118	acc = 1.000000
# portion = 0.02 #9866:	num_val = 118	acc = 1.000000
# portion = 0.02 #9867:	num_val = 118	acc = 1.000000
# portion = 0.02 #9868:	num_val = 118	acc = 1.000000
# portion = 0.02 #9869:	num_val = 118	acc = 1.000000
# portion = 0.02 #9870:	num_val = 118	acc = 0.991525
# portion = 0.02 #9871:	num_val = 118	acc = 0.974576
# portion = 0.02 #9872:	num_val = 118	acc = 1.000000
# portion = 0.02 #9873:	num_val = 118	acc = 1.000000
# portion = 0.02 #9874:	num_val = 118	acc = 1.000000
# portion = 0.02 #9875:	num_val = 118	acc = 1.000000
# portion = 0.02 #9876:	num_val = 118	acc = 0.991525
# portion = 0.02 #9877:	num_val = 118	acc = 1.000000
# portion = 0.02 #9878:	num_val = 118	acc = 1.000000
# portion = 0.02 #9879:	num_val = 118	acc = 0.991525
# portion = 0.02 #9880:	num_val = 118	acc = 1.000000
# portion = 0.02 #9881:	num_val = 118	acc = 1.000000
# portion = 0.02 #9882:	num_val = 118	acc = 0.991525
# portion = 0.02 #9883:	num_val = 118	acc = 1.000000
# portion = 0.02 #9884:	num_val = 118	acc = 1.000000
# portion = 0.02 #9885:	num_val = 118	acc = 0.983051
# portion = 0.02 #9886:	num_val = 118	acc = 1.000000
# portion = 0.02 #9887:	num_val = 118	acc = 1.000000
# portion = 0.02 #9888:	num_val = 118	acc = 0.991525
# portion = 0.02 #9889:	num_val = 118	acc = 0.983051
# portion = 0.02 #9890:	num_val = 118	acc = 0.991525
# portion = 0.02 #9891:	num_val = 118	acc = 0.991525
# portion = 0.02 #9892:	num_val = 118	acc = 0.991525
# portion = 0.02 #9893:	num_val = 118	acc = 0.991525
# portion = 0.02 #9894:	num_val = 118	acc = 0.991525
# portion = 0.02 #9895:	num_val = 118	acc = 0.991525
# portion = 0.02 #9896:	num_val = 118	acc = 1.000000
# portion = 0.02 #9897:	num_val = 118	acc = 1.000000
# portion = 0.02 #9898:	num_val = 118	acc = 1.000000
# portion = 0.02 #9899:	num_val = 118	acc = 1.000000
# portion = 0.02 #9900:	num_val = 118	acc = 0.991525
# portion = 0.02 #9901:	num_val = 118	acc = 1.000000
# portion = 0.02 #9902:	num_val = 118	acc = 0.991525
# portion = 0.02 #9903:	num_val = 118	acc = 1.000000
# portion = 0.02 #9904:	num_val = 118	acc = 1.000000
# portion = 0.02 #9905:	num_val = 118	acc = 1.000000
# portion = 0.02 #9906:	num_val = 118	acc = 1.000000
# portion = 0.02 #9907:	num_val = 118	acc = 0.991525
# portion = 0.02 #9908:	num_val = 118	acc = 1.000000
# portion = 0.02 #9909:	num_val = 118	acc = 0.983051
# portion = 0.02 #9910:	num_val = 118	acc = 0.991525
# portion = 0.02 #9911:	num_val = 118	acc = 1.000000
# portion = 0.02 #9912:	num_val = 118	acc = 0.991525
# portion = 0.02 #9913:	num_val = 118	acc = 1.000000
# portion = 0.02 #9914:	num_val = 118	acc = 1.000000
# portion = 0.02 #9915:	num_val = 118	acc = 0.974576
# portion = 0.02 #9916:	num_val = 118	acc = 1.000000
# portion = 0.02 #9917:	num_val = 118	acc = 1.000000
# portion = 0.02 #9918:	num_val = 118	acc = 0.991525
# portion = 0.02 #9919:	num_val = 118	acc = 0.983051
# portion = 0.02 #9920:	num_val = 118	acc = 0.991525
# portion = 0.02 #9921:	num_val = 118	acc = 1.000000
# portion = 0.02 #9922:	num_val = 118	acc = 1.000000
# portion = 0.02 #9923:	num_val = 118	acc = 0.991525
# portion = 0.02 #9924:	num_val = 118	acc = 1.000000
# portion = 0.02 #9925:	num_val = 118	acc = 0.991525
# portion = 0.02 #9926:	num_val = 118	acc = 1.000000
# portion = 0.02 #9927:	num_val = 118	acc = 0.983051
# portion = 0.02 #9928:	num_val = 118	acc = 0.974576
# portion = 0.02 #9929:	num_val = 118	acc = 0.991525
# portion = 0.02 #9930:	num_val = 118	acc = 1.000000
# portion = 0.02 #9931:	num_val = 118	acc = 1.000000
# portion = 0.02 #9932:	num_val = 118	acc = 0.991525
# portion = 0.02 #9933:	num_val = 118	acc = 0.991525
# portion = 0.02 #9934:	num_val = 118	acc = 1.000000
# portion = 0.02 #9935:	num_val = 118	acc = 1.000000
# portion = 0.02 #9936:	num_val = 118	acc = 1.000000
# portion = 0.02 #9937:	num_val = 118	acc = 0.983051
# portion = 0.02 #9938:	num_val = 118	acc = 0.991525
# portion = 0.02 #9939:	num_val = 118	acc = 0.983051
# portion = 0.02 #9940:	num_val = 118	acc = 0.991525
# portion = 0.02 #9941:	num_val = 118	acc = 1.000000
# portion = 0.02 #9942:	num_val = 118	acc = 1.000000
# portion = 0.02 #9943:	num_val = 118	acc = 1.000000
# portion = 0.02 #9944:	num_val = 118	acc = 0.991525
# portion = 0.02 #9945:	num_val = 118	acc = 1.000000
# portion = 0.02 #9946:	num_val = 118	acc = 0.991525
# portion = 0.02 #9947:	num_val = 118	acc = 0.983051
# portion = 0.02 #9948:	num_val = 118	acc = 0.991525
# portion = 0.02 #9949:	num_val = 118	acc = 1.000000
# portion = 0.02 #9950:	num_val = 118	acc = 1.000000
# portion = 0.02 #9951:	num_val = 118	acc = 1.000000
# portion = 0.02 #9952:	num_val = 118	acc = 1.000000
# portion = 0.02 #9953:	num_val = 118	acc = 0.991525
# portion = 0.02 #9954:	num_val = 118	acc = 1.000000
# portion = 0.02 #9955:	num_val = 118	acc = 0.991525
# portion = 0.02 #9956:	num_val = 118	acc = 1.000000
# portion = 0.02 #9957:	num_val = 118	acc = 0.991525
# portion = 0.02 #9958:	num_val = 118	acc = 1.000000
# portion = 0.02 #9959:	num_val = 118	acc = 0.974576
# portion = 0.02 #9960:	num_val = 118	acc = 1.000000
# portion = 0.02 #9961:	num_val = 118	acc = 0.991525
# portion = 0.02 #9962:	num_val = 118	acc = 1.000000
# portion = 0.02 #9963:	num_val = 118	acc = 1.000000
# portion = 0.02 #9964:	num_val = 118	acc = 0.991525
# portion = 0.02 #9965:	num_val = 118	acc = 1.000000
# portion = 0.02 #9966:	num_val = 118	acc = 0.991525
# portion = 0.02 #9967:	num_val = 118	acc = 1.000000
# portion = 0.02 #9968:	num_val = 118	acc = 0.983051
# portion = 0.02 #9969:	num_val = 118	acc = 1.000000
# portion = 0.02 #9970:	num_val = 118	acc = 0.991525
# portion = 0.02 #9971:	num_val = 118	acc = 1.000000
# portion = 0.02 #9972:	num_val = 118	acc = 1.000000
# portion = 0.02 #9973:	num_val = 118	acc = 1.000000
# portion = 0.02 #9974:	num_val = 118	acc = 1.000000
# portion = 0.02 #9975:	num_val = 118	acc = 1.000000
# portion = 0.02 #9976:	num_val = 118	acc = 1.000000
# portion = 0.02 #9977:	num_val = 118	acc = 0.991525
# portion = 0.02 #9978:	num_val = 118	acc = 1.000000
# portion = 0.02 #9979:	num_val = 118	acc = 1.000000
# portion = 0.02 #9980:	num_val = 118	acc = 0.991525
# portion = 0.02 #9981:	num_val = 118	acc = 0.991525
# portion = 0.02 #9982:	num_val = 118	acc = 0.991525
# portion = 0.02 #9983:	num_val = 118	acc = 0.991525
# portion = 0.02 #9984:	num_val = 118	acc = 1.000000
# portion = 0.02 #9985:	num_val = 118	acc = 1.000000
# portion = 0.02 #9986:	num_val = 118	acc = 0.983051
# portion = 0.02 #9987:	num_val = 118	acc = 0.991525
# portion = 0.02 #9988:	num_val = 118	acc = 1.000000
# portion = 0.02 #9989:	num_val = 118	acc = 1.000000
# portion = 0.02 #9990:	num_val = 118	acc = 1.000000
# portion = 0.02 #9991:	num_val = 118	acc = 0.991525
# portion = 0.02 #9992:	num_val = 118	acc = 0.991525
# portion = 0.02 #9993:	num_val = 118	acc = 1.000000
# portion = 0.02 #9994:	num_val = 118	acc = 1.000000
# portion = 0.02 #9995:	num_val = 118	acc = 0.983051
# portion = 0.02 #9996:	num_val = 118	acc = 1.000000
# portion = 0.02 #9997:	num_val = 118	acc = 0.991525
# portion = 0.02 #9998:	num_val = 118	acc = 1.000000
# portion = 0.02 #9999:	num_val = 118	acc = 1.000000
# FIN portion = 0.02:	num_val = 118.000000 +- 0.000000	acc = 0.992554 +- 0.029323

# %%
# plot accuracies obtained at different sizes
plt.figure()
plt.errorbar(x, y, y_err, x_err, marker='o')
plt.xlabel('number of validation images')
plt.ylabel('accuracy')
plt.legend('neural network')
